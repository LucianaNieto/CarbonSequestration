# %% [markdown]
# <a href="https://colab.research.google.com/github/LucianaNieto/CarbonSequestration/blob/main/SOC_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ----
# Objectives:

# %% [markdown]
# ### Libraries

# %%
# !pip install -q pycountry
# !pip install -q plotly --upgrade
# !pip install -q -U kaleido
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.3 MB/s eta 0:00:00

# %%
#Libraries
import pandas as pd
import numpy as np
import os
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import plotly.express as px
import plotly.graph_objects as go
from statsmodels.formula.api import ols
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Directories

# %%
# base path
base_path = '/content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/'

# Define paths for data and figure subdirectories
paths = {
    'raw_data_path': base_path + '01-Data/01-RawData/',
    'processed_data_path': base_path + '01-Data/02-ProcessedData/',
    'exploratory_figures_path': base_path + '02-Figures/01-Exploratory/',
    'final_figures_path': base_path + '02-Figures/02-Finals/',
    'raw_code_path': base_path + '03-Code/01-RawCode/',
    'data_processing_code_path': base_path + '03-Code/02-DataProcessing/',
    'data_analysis_code_path': base_path + '03-Code/03-DataAnalysis/',
    'clean_scripts_path': base_path + '03-Code/04-CleanScripts/'
}

# %% [markdown]
# ### Data loading

# %%
def load_data(file_name):
    csv_path = os.path.join(paths['processed_data_path'], f"{file_name}.csv")
    return pd.read_csv(csv_path)

df_effects = load_data('df_effects_SOC_filtered')
print("\nEffect-sizes Columns and Shape:")
print(df_effects.columns)
print(df_effects.shape)
# Out:
# Effect-sizes Columns and Shape:
# Index(['id', 'land_use', 'intervention', 'sub_cat_intervention', 'details',
#        'control (c)', 'treatment_authors', 'summary_effect_size', 'management',
#        'method', 'species', 'region_climate', 'soil', 'depth_original',
#        'depth', 'group_depth', 'depth2', 'duration', 'carbon', 'unit',
#        'rateyr', 'log_scale', 'metric', 'outcome', 'sub_cat_outcome',
#        'details_outcome', 'lower_ci', 'effect size', 'upper_ci', 'p_value',
#        'n_paired_data', 'es_se', 'duration_standardized'],
#       dtype='object')
# (5164, 33)

# %% [markdown]
# ### Modeling

# %%
custom_color_scale = ['#e3fef7','#003c43']
# Convert columns to numeric
numeric_cols = ['depth', 'duration_standardized']
for col in numeric_cols:
    df_effects[col] = pd.to_numeric(df_effects[col], errors='coerce')

# Fill missing values for numeric columns
df_effects[numeric_cols] = df_effects[numeric_cols].fillna(df_effects[numeric_cols].mean())

# Fill missing values for categorical columns
categorical_cols = ['land_use']
df_effects[categorical_cols] = df_effects[categorical_cols].fillna('Unknown')

# ANOVA for effect size by land use
anova_model = ols('Q("effect size") ~ C(land_use)', data=df_effects).fit()
anova_table = sm.stats.anova_lm(anova_model, typ=2)
print(anova_table)

# Boxplot of effect size by land use
fig = px.box(df_effects, x='land_use', y='effect size',
             title='Effect Size by Land Use',
             labels={'land_use': 'Land Use', 'effect size': 'Effect Size'},
             color_discrete_sequence=[custom_color_scale[0]])
fig.update_layout(
    plot_bgcolor='#003c43',
    paper_bgcolor='#003c43',
    title_font=dict(color=custom_color_scale[0]),
    font=dict(color=custom_color_scale[0]),
    xaxis=dict(title_font=dict(color=custom_color_scale[0]), tickfont=dict(color=custom_color_scale[0])),
    yaxis=dict(title_font=dict(color=custom_color_scale[0]), tickfont=dict(color=custom_color_scale[0]))
)

fig.show()
# Out:
#                   sum_sq      df           F         PR(>F)
# C(land_use)   242.642214    10.0  102.627693  8.363162e-195
# Residual     1218.321574  5153.0         NaN            NaN
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="9ca100f4-6f61-482c-849f-cae7c7987708" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ca100f4-6f61-482c-849f-cae7c7987708")) {                    Plotly.newPlot(                        "9ca100f4-6f61-482c-849f-cae7c7987708",                        [{"alignmentgroup":"True","hovertemplate":"Land Use=%{x}\u003cbr\u003eEffect Size=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#e3fef7"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","forest land","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","cropland","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","cropland","cropland","cropland","cropland","cropland","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","grassland","grassland","land_use change","land_use change","land_use change","land_use change","grassland","grassland","grassland","grassland","grassland","grassland","grassland","grassland","grassland","land_use change","land_use change","grassland","grassland","land_use change","land_use change","various land uses","various land uses","cropland","cropland","cropland","cropland","land_use change","land_use change","cropland","land_use change","land_use change","land_use change","cropland","land_use change","land_use change","land_use change","land_use change","grassland","various land uses","cropland","cropland","cropland","cropland","various land uses","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","various land uses","various land uses","various land uses","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","grassland","various land uses","various land uses","various land uses","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use change","land_use chang ...

# %%
# Tukey's HSD test
tukey = pairwise_tukeyhsd(endog=df_effects['effect size'], groups=df_effects['land_use'], alpha=0.05)
print(tukey.summary())

# Extract Tukey HSD results
tukey_results = pd.DataFrame(data=tukey._results_table.data[1:], columns=tukey._results_table.data[0])

# Plot the results with Plotly
fig = go.Figure()

for i in range(len(tukey_results)):
    row = tukey_results.iloc[i]
    fig.add_trace(go.Scatter(
        x=[row['lower'], row['upper']],
        y=[row['group1'] + ' vs ' + row['group2']] * 2,
        mode='lines',
        line=dict(color='#b0e0e6', width=2),
        showlegend=False
    ))
    fig.add_trace(go.Scatter(
        x=[(row['meandiff'])],
        y=[row['group1'] + ' vs ' + row['group2']],
        mode='markers',
        marker=dict(color='#b0e0e6', size=10),
        showlegend=False
    ))

fig.update_layout(
    title='Tukey HSD Test Results',
    xaxis_title='Mean Difference',
    yaxis_title='Group Comparison',
    plot_bgcolor='#003c43',
    paper_bgcolor='#003c43',
    title_font=dict(color=custom_color_scale[0]),
    font=dict(color=custom_color_scale[0]),
    xaxis=dict(title_font=dict(color=custom_color_scale[0]), tickfont=dict(color=custom_color_scale[0]), showgrid=False),
    yaxis=dict(title_font=dict(color=custom_color_scale[0]), tickfont=dict(color=custom_color_scale[0]), showgrid=False)
)

fig.show()
# Out:
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================
#       group1             group2       meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------
#           cropland             desert  -0.3486 0.8072 -0.9888  0.2915  False
#           cropland        forest land  -0.3113    0.0 -0.3798 -0.2429   True
#           cropland          grassland  -0.6346    0.0   -0.72 -0.5491   True
#           cropland    land_use change  -0.2256    0.0 -0.2848 -0.1663   True
#           cropland other land:various  -0.9803 0.0004 -1.6814 -0.2792   True
#           cropland         shrublands  -0.1839  0.682 -0.4873  0.1194  False
#           cropland             tundra  -0.5127 0.0211 -0.9861 -0.0394   True
#           cropland            various  -1.1294 0.0002 -1.9131 -0.3458   True
#           cropland  various land uses  -0.4112    0.0 -0.4746 -0.3479   True
#           cropland           wetlands  -1.1711    0.0 -1.4459 -0.8963   True
#             desert        forest land   0.0373    1.0 -0.6046  0.6792  False
#             desert          grassland   -0.286 0.9411 -0.9299   0.358  False
#             desert    land_use change    0.123 0.9999  -0.518  0.7641  False
#             desert other land:various  -0.6317 0.5443 -1.5798  0.3164  False
#             desert         shrublands   0.1647 0.9996  -0.542  0.8714  False
#             desert             tundra  -0.1641 0.9999 -0.9587  0.6305  False
#             desert            various  -0.7808 0.3118 -1.7915  0.2299  False
#             desert  various land uses  -0.0626    1.0  -0.704  0.5788  False
#             desert           wetlands  -0.8225 0.0066 -1.5174 -0.1276   True
#        forest land          grassland  -0.3233    0.0 -0.4211 -0.2254   True
#        forest land    land_use change   0.0857 0.0129  0.0097  0.1618   True
#        forest land other land:various   -0.669 0.0787 -1.3717  0.0337  False
#        forest land         shrublands   0.1274 0.9626 -0.1797  0.4344  False
#        forest land             tundra  -0.2014 0.9571 -0.6772  0.2744  False
#        forest land            various  -0.8181 0.0327 -1.6032  -0.033   True
#        forest land  various land uses  -0.0999 0.0025 -0.1792 -0.0206   True
#        forest land           wetlands  -0.8598    0.0 -1.1386 -0.5809   True
#          grassland    land_use change    0.409    0.0  0.3173  0.5007   True
#          grassland other land:various  -0.3457 0.8909 -1.0503  0.3588  False
#          grassland         shrublands   0.4506 0.0002  0.1394  0.7619   True
#          grassland             tundra   0.1219 0.9992 -0.3566  0.6004  False
#          grassland            various  -0.4948 0.6311 -1.2816  0.2919  False
#          grassland  various land uses   0.2234    0.0   0.129  0.3177   True
#          grassland           wetlands  -0.5365    0.0   -0.82  -0.253   True
#    land_use change other land:various  -0.7547  0.023 -1.4566 -0.0529   True
#    land_use change         shrublands   0.0416    1.0 -0.2635  0.3468  False
#    land_use change             tundra  -0.2871 0.6849 -0.7617  0.1874  False
#    land_use change            various  -0.9038 0.0096 -1.6882 -0.1195   True
#    land_use change  various land uses  -0.1856    0.0 -0.2572 -0.1141   True
#    land_use change           wetlands  -0.9455    0.0 -1.2223 -0.6688   True
# other land:various         shrublands   0.7964 0.0318  0.0341  1.5587   True
# other land:various             tundra   0.4676 0.7905 -0.3769  1.3121  False
# other land:various            various  -0.1491    1.0 -1.1994  0.9012  False
# other land:various  various land uses   0.5691 0.2438 -0.1331  1.2713  False
# other land:various           wetlands  -0.1908 0.9992 -0.9422  0.5606  False
#         shrublands             tundra  -0.3288 0.7239 -0.8888  0.2313  False
#         shrublands            various  -0.9455 0.0128 -1.7843 -0.1066   True
#         shrublands  various land uses  -0.2273 0.3717 -0.5332  0.0787  False
#         shrublands           wetlands  -0.9872    0.0 -1.3935 -0.5808   True
#             tundra            various  -0.6167 0.5249 -1.5309  0.2975  False
#             tundra  various land uses   0.1015 0.9998 -0.3736  0.5765  False
#             tundra           wetlands  -0.6584 0.0049 -1.2035 -0.1133   True
#            various  various land uses   0.7182 0.1088 -0.0665  1.5029  False
#            various           wetlands  -0.0417    1.0 -0.8706  0.7873  False
#  various land uses           wetlands  -0.7599    0.0 -1.0375 -0.4822   True
# ----------------------------------------------------------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="06df002b-7c27-4cc2-8e22-65f21746e661" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06df002b-7c27-4cc2-8e22-65f21746e661")) {                    Plotly.newPlot(                        "06df002b-7c27-4cc2-8e22-65f21746e661",                        [{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.9888,0.2915],"y":["cropland vs desert","cropland vs desert"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.3486],"y":["cropland vs desert"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.3798,-0.2429],"y":["cropland vs forest land","cropland vs forest land"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.3113],"y":["cropland vs forest land"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.72,-0.5491],"y":["cropland vs grassland","cropland vs grassland"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.6346],"y":["cropland vs grassland"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.2848,-0.1663],"y":["cropland vs land_use change","cropland vs land_use change"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.2256],"y":["cropland vs land_use change"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-1.6814,-0.2792],"y":["cropland vs other land:various","cropland vs other land:various"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.9803],"y":["cropland vs other land:various"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.4873,0.1194],"y":["cropland vs shrublands","cropland vs shrublands"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.1839],"y":["cropland vs shrublands"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.9861,-0.0394],"y":["cropland vs tundra","cropland vs tundra"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.5127],"y":["cropland vs tundra"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-1.9131,-0.3458],"y":["cropland vs various","cropland vs various"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-1.1294],"y":["cropland vs various"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.4746,-0.3479],"y":["cropland vs various land uses","cropland vs various land uses"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-0.4112],"y":["cropland vs various land uses"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-1.4459,-0.8963],"y":["cropland vs wetlands","cropland vs wetlands"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[-1.1711],"y":["cropland vs wetlands"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"lines","showlegend":false,"x":[-0.6046,0.6792],"y":["desert vs forest land","desert vs forest land"],"type":"scatter"},{"marker":{"color":"#b0e0e6","size":10},"mode":"markers","showlegend":false,"x":[0.0373],"y":["desert vs forest land"],"type":"scatter"},{"line":{"color":"#b0e0e6","width":2},"mode":"l ...

# %%
# Interaction effect model
interaction_model = ols('Q("effect size") ~ C(land_use) * depth + C(land_use) * duration_standardized', data=df_effects).fit()
interaction_anova_table = sm.stats.anova_lm(interaction_model, typ=2)
print(interaction_anova_table)
# Out:
#                                         sum_sq      df           F  \
# C(land_use)                         286.256934    10.0  122.528447
# depth                                 0.313509     1.0    1.341935
# C(land_use):depth                    13.466928    10.0    5.764338
# duration_standardized                 0.188923     1.0    0.808661
# C(land_use):duration_standardized    24.996776    10.0   10.699535
# Residual                           1200.130996  5137.0         NaN
#
#                                           PR(>F)
# C(land_use)                        1.823104e-188
# depth                               2.467468e-01
# C(land_use):depth                   1.137253e-08
# duration_standardized               3.685587e-01
# C(land_use):duration_standardized   3.443269e-18
# Residual                                     NaN
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:1894: ValueWarning:
#
# covariance of constraints does not have full rank. The number of constraints is 10, but rank is 8

# %% [markdown]
# ----
# ----
#
# **Results**
#
# The analysis of variance (ANOVA) and Tukey's Honest Significant Difference (HSD) test were conducted to evaluate the effect of land use on effect size. The ANOVA results revealed that land use significantly affects effect size (F(10, 5153) = 102.63, p < 0.001). Additionally, significant interactions were observed between land use and depth (F(10, 5137) = 5.76, p < 0.001) and between land use and standardized duration (F(10, 5137) = 10.70, p < 0.001).
#
# The Tukey HSD test further elucidated these relationships by identifying specific pairwise differences between land use categories. Significant differences in effect size were found between various land use types, notably between cropland and forest land (mean difference = -0.3113, p < 0.001), cropland and grassland (mean difference = -0.6346, p < 0.001), and cropland and wetlands (mean difference = -1.1711, p < 0.001). These results indicate that cropland consistently exhibits a lower effect size compared to these other land use categories.
#
# The interaction model incorporating land use, depth, and standardized duration demonstrated that both depth and standardized duration significantly interact with land use to influence effect size. Specifically, the interactions between land use and depth (F(10, 5137) = 5.76, p < 0.001) and between land use and standardized duration (F(10, 5137) = 10.70, p < 0.001) underscore the complexity of these relationships.
#
# **Discussion**
#
# The findings from this study underscore the pivotal role of land use in determining effect size, with cropland exhibiting a notably lower effect size compared to other land use types such as forest land, grassland, and wetlands. The significant interactions between land use and both depth and standardized duration suggest that the effect of land use on effect size is modulated by these factors.
#
# The ANOVA results provide robust evidence that land use is a critical determinant of effect size, accounting for a substantial portion of the variance. The Tukey HSD test complements this by specifying the pairwise differences, highlighting the particularly low effect size associated with cropland. This is consistent with the hypothesis that different land use practices impact ecological outcomes differently, with cropland potentially leading to more degraded or less favorable conditions.
#
# The interaction effects identified in the model suggest that the impact of land use on effect size cannot be fully understood without considering the modifying effects of depth and standardized duration. This indicates that land management practices need to be tailored not only to the type of land use but also to specific conditions such as soil depth and the duration of land use practices.
#
# In conclusion, this study provides compelling evidence that land use, depth, and duration are interlinked factors influencing ecological outcomes, as measured by effect size. Future research should focus on elucidating the mechanisms driving these interactions and on developing land management strategies that mitigate negative impacts while enhancing positive outcomes in diverse ecological contexts.
