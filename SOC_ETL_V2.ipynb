# %% [markdown]
# <a href="https://colab.research.google.com/github/LucianaNieto/CarbonSequestration/blob/main/SOC_ETL_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * Loading the Data from Excel
# * Cleaning and Normalizing Text Data
# * Mapping Values
# * Standardizing Metrics
# * Filtering Data
# * Dropping Unnecessary Columns
# * Standardizing Country Names
# * Creating Directories
# * Saving the Processed Data

# %% [markdown]
# ### Libraries

# %%
# !pip install -q pycountry fuzzywuzzy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 21.5 MB/s eta 0:00:00

# %%
# Import necessary libraries
import pandas as pd
import os
import numpy as np
from pycountry import countries
from fuzzywuzzy import process
import re
import traceback

# %% [markdown]
# ### Directories

# %%
# Define base path and subdirectory paths
base_path = '/content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/'
paths = {
    'raw_data_path': base_path + '01-Data/01-RawData/',
    'processed_data_path': base_path + '01-Data/02-ProcessedData/',
    'exploratory_figures_path': base_path + '02-Figures/01-Exploratory/',
    'final_figures_path': base_path + '02-Figures/02-Finals/',
    'raw_code_path': base_path + '03-Code/01-RawCode/',
    'data_processing_code_path': base_path + '03-Code/02-DataProcessing/',
    'data_analysis_code_path': base_path + '03-Code/03-DataAnalysis/',
    'clean_scripts_path': base_path + '03-Code/04-CleanScripts/'
}

# %% [markdown]
# ### Funtions

# %%
# Check and create directory if it does not exist
def check_create_directory(path):
    try:
        if not os.path.exists(path):
            os.makedirs(path)
            print(f"Directory created: {path}")
        else:
            print(f"Directory already exists: {path}")
    except Exception as e:
        print(f"Failed to check or create directory {path}. Error: {e}")
        traceback.print_exc()

def load_data(sheet_name):
    csv_path = os.path.join(paths['processed_data_path'], f"{sheet_name}.csv")
    return pd.read_csv(csv_path)

def print_unique_values(df, column_list):
    for column in column_list:
        unique_values = df[column].unique()
        print(f"Unique values in {column}: {unique_values}\nTotal unique in {column}: {len(unique_values)}")


def clean_column_names(df):
    """Clean column names by stripping whitespace and converting to lowercase."""
    df.columns = df.columns.str.strip().str.lower()
    return df


def normalize_text(df, column):
    """Normalize text data in a specified column."""
    df[column] = df[column].str.lower().str.strip()
    df[column] = df[column].str.replace(' ; ', ',').str.replace(' -> ', '->')
    df[column] = df[column].str.replace(' : ', ':').str.replace(' , ', ',').str.replace(', ', ',')
    return df


def map_control_values(df, column, mapping):
    """Map control values to standardized categories."""
    df[column] = df[column].map(mapping).fillna(df[column])
    return df

def standardize_metrics(df, metrics):
    """Standardize metrics and filter data."""
    df['metric'] = df['metric'].str.lower()
    return df[df['metric'].isin(metrics)]

def convert_to_ratio(value):
    """Convert percentage to ratio."""
    try:
        return 1 + (float(value) / 100)
    except (ValueError, TypeError):
        return value  # Return original value if conversion fails

def apply_transformations(df, condition, columns):
    """Apply transformations to specified columns under a condition."""
    for column in columns:
        df.loc[condition, column] = df.loc[condition, column].apply(convert_to_ratio)
    return df


def standardize_country_names(country_name):
    if pd.isna(country_name):
        return 'None'
    country_name = country_name.strip().lower()
    # Handling general identifiers like 'Global' or 'All continents'
    if country_name in ['global', 'all continents', 'world', 'worldwide']:
        return 'Global'
    # Splitting entries with multiple countries
    if ',' in country_name:
        country_parts = country_name.split(',')
        standardized_parts = [standardize_single_country(part.strip()) for part in country_parts if part.strip()]
        return ', '.join(standardized_parts)
    # Standardize a single country name
    return standardize_single_country(country_name)

def standardize_single_country(single_country):
    single_country = ''.join(e for e in single_country if e.isalnum() or e.isspace())
    try:
        # If the country name is a direct match
        return countries.lookup(single_country).name
    except LookupError:
        # If no direct match, use fuzzy matching to find the closest valid country name
        possible_matches = [country.name for country in countries]
        closest_match = process.extractOne(single_country, possible_matches, score_cutoff=80)
        if closest_match:
            return closest_match[0]
        return 'None'

def standardize_duration(duration):
    if pd.isna(duration):
        return None
    duration = duration.strip().lower()

    # Convert durations in days to years
    if 'day' in duration:
        days = re.findall(r'\d+', duration)
        if days:
            return float(days[0]) / 365
    # Convert durations in months to years
    elif 'month' in duration:
        months = re.findall(r'\d+', duration)
        if months:
            return float(months[0]) / 12
    # Convert durations in years
    elif 'yr' in duration or 'year' in duration:
        duration = duration.replace('yr', '').replace('year', '').strip()

    # Handle ranges
    if '-' in duration:
        parts = duration.split('-')
        try:
            return float(parts[1])  # Take the higher value
        except ValueError:
            return None
    if '>' in duration:
        try:
            return float(duration.replace('>', '').strip())
        except ValueError:
            return None
    if '<' in duration:
        try:
            return float(duration.replace('<', '').strip())
        except ValueError:
            return None
    try:
        return float(re.findall(r'\d+', duration)[0])
    except (ValueError, IndexError):
        return None


def normalize_depth(value):
    if pd.isna(value):
        return np.nan

    value = value.strip().lower()

    # Handle range
    match = re.match(r'(\d+)\s*-\s*(\d+)\s*cm', value)
    if match:
        _, high = map(int, match.groups())
        return high

    # Handle single values
    match = re.match(r'(\d+)\s*cm', value)
    if match:
        return int(match.group(1))

    # Handle cases like '>30 cm'
    match = re.match(r'>(\d+)\s*cm', value)
    if match:
        return int(match.group(1))

    # For any other non-numeric values, return NaN
    return np.nan

# %% [markdown]
# ### Data loading

# %%
for path in paths.values():
    check_create_directory(path)
# Out:
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/01-RawData/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/02-Figures/01-Exploratory/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/02-Figures/02-Finals/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/03-Code/01-RawCode/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/03-Code/02-DataProcessing/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/03-Code/03-DataAnalysis/
# Directory already exists: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/03-Code/04-CleanScripts/

# %%
#load data and read sheets
excel_file_name = 'SOC_db.xlsx'
excel_file_path = os.path.join(paths['raw_data_path'], excel_file_name)
try:
    xls = pd.ExcelFile(excel_file_path)
    print(xls.sheet_names)
except Exception as e:
    print(f"An error occurred while loading the Excel file: {e}")

# Dictionary to hold dataframes for each sheet
sheets_df = {}

for sheet_name in xls.sheet_names:
    sheets_df[sheet_name] = pd.read_excel(xls, sheet_name=sheet_name)
    print(f"////////////////First few rows of {sheet_name}:")
    print(sheets_df[sheet_name].head())

    # stat
    print(f"////////////////Info for {sheet_name}:")
    sheets_df[sheet_name].info()
    print(f"////////////////Description for {sheet_name}:")
    print(sheets_df[sheet_name].describe())
# Out:
# ['readme', 'header_names', 'retained_meta-analyses', 'non_retained_meta-analyses', 'Effect-sizes', 'Primary_studies']
# ////////////////First few rows of readme:
#            Unnamed: 0  Unnamed: 1  \
# 0                 NaN         NaN
# 1  Global information         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
#
#                                           Unnamed: 2
# 0                                                NaN
# 1                      Data associated to the paper:
# 2                                                NaN
# 3  A global database of land management, land-use...
# 4  Authors: Damien Beillouin1,2*, Julien Demenois...
# ////////////////Info for readme:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      object
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  28 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 992.0+ bytes
# ////////////////Description for readme:
#        Unnamed: 1
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# ////////////////First few rows of header_names:
#                        Unnamed: 0         Unnamed: 1  \
# 0  Sheet "retained meta-analyses"                NaN
# 1                   Column_header              Theme
# 2                              ID            General
# 3               SOC_as_covariable                NaN
# 4                    Quality-Unit  Quality appraisal
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1                                        Description
# 2                            ID of the meta-analysis
# 3  Is the SOC presented as a co-variable in the m...
# 4         Is the unit of the carbon clearly defined?
#
#                      Unnamed: 3
# 0                           NaN
# 1                       Details
# 2  Common ID with other tablets
# 3            manually retrieved
# 4            manually retrieved
# ////////////////Info for header_names:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  122 non-null    object
#  1   Unnamed: 1  117 non-null    object
#  2   Unnamed: 2  118 non-null    object
#  3   Unnamed: 3  115 non-null    object
# dtypes: object(4)
# memory usage: 4.1+ KB
# ////////////////Description for header_names:
#        Unnamed: 0 Unnamed: 1   Unnamed: 2          Unnamed: 3
# count         122        117          118                 115
# unique        102         15           96                   5
# top            ID  Meta-data  Description  manually retrieved
# freq            4         46            4                  62
# ////////////////First few rows of retained_meta-analyses:
#                        ID SOC_as_covariable Quality_Unit  \
# 0  07_Sagrilo et al, 2015               YES          NaN
# 1     10_Nave et al, 2011                NO      YES, MM
# 2   1004_Jian et al, 2020                NO           NO
# 3  1004_Jian et al, 2020b                NO           NO
# 4    1005_Gao et al, 2020                NO      YES, MM
#
#   Quality_appraisal of primary studies Quality_Lit_gray_and_peer  \
# 0                                 none                        NO
# 1                                 none                       YES
# 2                                 none                       YES
# 3                                 none                       YES
# 4                                 none                        NO
#
#   Quality_Lit_Nb_database Quality_Lit_strings_OK  \
# 0                       2                    YES
# 1                       4             not writen
# 2                       4                    YES
# 3                       4                    YES
# 4                       2                    YES
#
#   Quality_Lit_inclusion_exclusion                       Quality_Model  \
# 0        YES (clearly mentionned)              YES, clearly described
# 1        YES (clearly mentionned)              yes, clearly described
# 2        YES (clearly mentionned)  not clear/no meta-analytical model
# 3        YES (clearly mentionned)  not clear/no meta-analytical model
# 4        YES (clearly mentionned)  not clear/no meta-analytical model
#
#       Quality_Model_weights  ...  \
# 0  YES, inverse of variance  ...
# 1                unweighted  ...
# 2   Not clear/not indicated  ...
# 3   Not clear/not indicated  ...
# 4   YES, Nb replicates/data  ...
#
#                                        Keywords Plus  \
# 0  GREENHOUSE-GAS EMISSIONS; FAST PYROLYSIS BIOCH...
# 1  COARSE WOODY DEBRIS; ORGANIC-MATTER; TERRESTRI...
# 2  MICROBIAL COMMUNITY STRUCTURE; CONSERVATION TI...
# 3                                                NaN
# 4  NITROGEN; CARBON; VEGETATION; REGION; PLANTATI...
#
#                                            Addresses         Email Addresses  \
# 0  [Sagrilo, Edvaldo] Embrapa Mid North, BR-64006...  edvaldo.sagrilo@wur.nl
# 1  [Nave, Lucas E.; Curtis, Peter S.] Ohio State ...      lukenave@umich.edu
# 2  [Jian, Jinshi; Lester, Brandon J.; Du, Xuan; R...     ryan.stewart@vt.edu
# 3                                                NaN                     NaN
# 4  [Gao, Han; Huang, Yimei] Northwest A&F Univ, C...                     NaN
#
#                                         Funding Orgs Cited Reference Count  \
# 0                                            Embrapa                  90.0
# 1  USDA-Forest Service Northern Research StationU...                  78.0
# 2  U.S. Department of Agriculture NRCS Conservati...                  39.0
# 3                                                NaN                   NaN
# 4  International Partnership Program of the Chine...                  48.0
#
#   Times Cited, WoS Core Times Cited, All Databases  \
# 0                  34.0                       40.0
# 1                 105.0                      111.0
# 2                   2.0                        2.0
# 3                   NaN                        NaN
# 4                   0.0                        0.0
#
#                                       WoS Categories  \
# 0  Agronomy; Biotechnology & Applied Microbiology...
# 1                    Ecology; Environmental Sciences
# 2                                       Soil Science
# 3                                                NaN
# 4                                           Forestry
#
#                                       Research Areas  reviewer
# 0  Agriculture; Biotechnology & Applied Microbiol...  Frederic
# 1                   Environmental Sciences & Ecology     David
# 2                                        Agriculture    Damien
# 3                                                NaN    Damien
# 4                                           Forestry    Damien
#
# [5 rows x 40 columns]
# ////////////////Info for retained_meta-analyses:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ID                                       217 non-null    object
#  1   SOC_as_covariable                        217 non-null    object
#  2   Quality_Unit                             199 non-null    object
#  3   Quality_appraisal of primary studies     217 non-null    object
#  4   Quality_Lit_gray_and_peer                217 non-null    object
#  5   Quality_Lit_Nb_database                  217 non-null    object
#  6   Quality_Lit_strings_OK                   217 non-null    object
#  7   Quality_Lit_inclusion_exclusion          217 non-null    object
#  8   Quality_Model                            217 non-null    object
#  9   Quality_Model_weights                    217 non-null    object
#  10  Quality_Model_heterogeneity (I2, PI, …)  217 non-null    object
#  11  Quality_Publication_bias                 217 non-null    object
#  12  soil_depth                               217 non-null    object
#  13  length_time_series                       215 non-null    object
#  14  Quality_Data_Sharing                     217 non-null    object
#  15  Population: geographical scale           201 non-null    object
#  16  Field experiment                         217 non-null    object
#  17  Lab, incubation, greenhouse              216 non-null    object
#  18  Other                                    216 non-null    object
#  19  Mitigation                               217 non-null    int64
#  20  Adaptation                               217 non-null    int64
#  21  FoodSecurity                             217 non-null    int64
#  22  Source                                   217 non-null    object
#  23  Article Title                            217 non-null    object
#  24  Abstract                                 217 non-null    object
#  25  Keywords                                 210 non-null    object
#  26  Authors                                  217 non-null    object
#  27  Year                                     217 non-null    int64
#  28  Journal                                  217 non-null    object
#  29  link                                     216 non-null    object
#  30  Keywords Plus                            203 non-null    object
#  31  Addresses                                196 non-null    object
#  32  Email Addresses                          201 non-null    object
#  33  Funding Orgs                             176 non-null    object
#  34  Cited Reference Count                    203 non-null    float64
#  35  Times Cited, WoS Core                    203 non-null    float64
#  36  Times Cited, All Databases               203 non-null    float64
#  37  WoS Categories                           198 non-null    object
#  38  Research Areas                           203 non-null    object
#  39  reviewer                                 217 non-null    object
# dtypes: float64(3), int64(4), object(33)
# memory usage: 67.9+ KB
# ////////////////Description for retained_meta-analyses:
#        Mitigation  Adaptation  FoodSecurity         Year  \
# count  217.000000  217.000000    217.000000   217.000000
# mean     0.917051    0.129032      0.253456  2015.672811
# std      0.276443    0.336011      0.435996     3.671568
# min      0.000000    0.000000      0.000000  2001.000000
# 25%      1.000000    0.000000      0.000000  2014.000000
# 50%      1.000000    0.000000      0.000000  2017.000000
# 75%      1.000000    0.000000      1.000000  2018.000000
# max      1.000000    1.000000      1.000000  2020.000000
#
#        Cited Reference Count  Times Cited, WoS Core  \
# count             203.000000             203.000000
# mean               83.369458              87.788177
# std                51.987684             204.420503
# min                25.000000               0.000000
# 25%                54.000000               8.000000
# 50%                72.000000              29.000000
# 75%                95.500000              65.000000
# max               448.000000            2020.000000
#
#        Times Cited, All Databases
# count                  203.000000
# mean                   121.211823
# std                    380.279508
# min                      0.000000
# 25%                      9.500000
# 50%                     32.000000
# 75%                     78.500000
# max                   4439.000000
# ////////////////First few rows of non_retained_meta-analyses:
#                        ID Source Out_of_subject Not_a_meta_analysis  \
# 0     2_Mastelloset al,NA    WOS            YES                   -
# 1        3_Laniniet al,NA    WOS            YES                   -
# 2         4_Eberzet al,NA    WOS            YES                   -
# 3  5_Houghton et al, 2004    WOS              -                 YES
# 4         6_Weberet al,NA    WOS            YES                   -
#
#   NO_Effect_size_on_SOC Other Comments        Outcome  \
# 0                     -     -       Na  medical study
# 1                     -     -       Na  medical study
# 2                     -     -       Na  medical study
# 3                     -     -   Review            NaN
# 4                     -     -       Na  medical study
#
#                                                title  \
# 0  Transtheoretical model stages of change for di...
# 1  Triple therapy for hepatitis c improves viral ...
# 2  The timp-inventory - a contribution to the ide...
# 3  Effects of land-use change on the carbon balan...
# 4  Learning on the job, the use of selection, opt...
#
#                                              Authors  \
# 0  Mastellos, N; Gunn, LH; Felix, LM; Car, J; Maj...
# 1  Lanini, S; Mammone, A; Puro, V; Girardi, E; Br...
# 2                               Eberz, S; Antoni, CH
# 3                          Houghton, RA; Goodale, CL
# 4  Weber, J; Jorres, R; Kronseder, A; Muller, A; ...
#
#                                              JOURNAL  \
# 0            COCHRANE DATABASE OF SYSTEMATIC REVIEWS
# 1                                 NEW MICROBIOLOGICA
# 2  GIO-GRUPPE-INTERAKTION-ORGANISATION-ZEITSCHRIF...
# 3                     ECOSYSTEMS AND LAND USE CHANGE
# 4  INTERNATIONAL ARCHIVES OF OCCUPATIONAL AND ENV...
#
#                                             Keywords  \
# 0                                                NaN
# 1                                                NaN
# 2  Leadership; Health; Sense of coherence; Intera...
# 3                                                NaN
# 4  Learning opportunities; Selection; optimizatio...
#
#                                             Abstract CitesURL  \
# 0  Background Obesity is a global public health t...      NaN
# 1  This meta-analysis assesses the efficacy and s...      NaN
# 2  Occupational health management and science inc...      NaN
# 3  Most changes in land use affect the amount of ...      NaN
# 4  PurposeDue to the increased need for retention...      NaN
#
#                                   lien pour accès reviewer
# 0  https://doi.org/10.1002/14651858.CD008066.pub3  Abigail
# 1                                             NaN  Abigail
# 2       https://doi.org/10.1007/s11612-017-0384-4  Abigail
# 3                 https://doi.org/10.1029/153GM08  Abigail
# 4      https://doi.org/10.1007/s00420-019-01408-5  Abigail
# ////////////////Info for non_retained_meta-analyses:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790 entries, 0 to 789
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     790 non-null    object
#  1   Source                 790 non-null    object
#  2   Out_of_subject         790 non-null    object
#  3   Not_a_meta_analysis    790 non-null    object
#  4   NO_Effect_size_on_SOC  790 non-null    object
#  5   Other                  790 non-null    object
#  6   Comments               543 non-null    object
#  7   Outcome                502 non-null    object
#  8   title                  790 non-null    object
#  9   Authors                778 non-null    object
#  10  JOURNAL                341 non-null    object
#  11  Keywords               312 non-null    object
#  12  Abstract               640 non-null    object
#  13  CitesURL               80 non-null     object
#  14  lien pour accès        648 non-null    object
#  15  reviewer               790 non-null    object
# dtypes: object(16)
# memory usage: 98.9+ KB
# ////////////////Description for non_retained_meta-analyses:
#                          ID Source Out_of_subject Not_a_meta_analysis  \
# count                   790    790            790                 790
# unique                  790     24              2                   2
# top     2_Mastelloset al,NA    WOS              -                   -
# freq                      1    521            515                 476
#
#        NO_Effect_size_on_SOC Other Comments Outcome  \
# count                    790   790      543     502
# unique                     2     4       72     456
# top                        -     -  Article     SOC
# freq                     609   770      209      13
#
#                                                     title  \
# count                                                 790
# unique                                                780
# top     Warming induced changes in soil carbon and nit...
# freq                                                    2
#
#                           Authors                JOURNAL       Keywords  \
# count                         778                    341            312
# unique                        771                    148            307
# top     Eriksson, M; Lindstrom, B  GLOBAL CHANGE BIOLOGY  meta-analysis
# freq                            3                     31              3
#
#                                                  Abstract  \
# count                                                 640
# unique                                                640
# top     Background Obesity is a global public health t...
# freq                                                    1
#
#                                                  CitesURL  \
# count                                                  80
# unique                                                 80
# top     https://scholar.google.com/scholar?cites=87091...
# freq                                                    1
#
#                                          lien pour accès reviewer
# count                                                648      790
# unique                                               646        8
# top     https://doi.org/10.1111/j.1365-2486.2006.01117.x   Damien
# freq                                                   2      338
# ////////////////First few rows of Effect-sizes:
#        NUM                      ID   Figure   Land_use Intervention  \
# 0  14556.0  07_Sagrilo et al, 2015    Fig 1   cropland  management
# 1  14557.0  07_Sagrilo et al, 2015    Fig 1   cropland  management
# 2  14558.0  07_Sagrilo et al, 2015    Fig 1   cropland  management
# 3  14559.0  07_Sagrilo et al, 2015  Table 1   cropland  management
# 4  14560.0  07_Sagrilo et al, 2015  Table 1   cropland  management
#
#    Sub_Cat_intervention               details Control (C) treatment_authors  \
# 0  amendments pyrogenic  amendments : biochar  No biochar           Biochar
# 1  amendments pyrogenic  amendments : biochar  No biochar           Biochar
# 2  amendments pyrogenic  amendments : biochar  No biochar           Biochar
# 3  amendments pyrogenic  amendments : biochar  No biochar           Biochar
# 4  amendments pyrogenic  amendments : biochar  No biochar           Biochar
#
#   summary_effect_size  ... details_outcome Homogenized_response  lower_CI  \
# 0                 NaN  ...       emissions        CO2 emissions  0.932927
# 1                 NaN  ...       emissions        CO2 emissions  1.143293
# 2                 NaN  ...       emissions        CO2 emissions  1.554878
# 3                 NaN  ...       emissions        CO2 emissions      1.57
# 4                 NaN  ...       emissions        CO2 emissions      1.05
#
#   Effect size  upper_CI p_value N_paired_data ES_SE comments Reviewer
# 0    1.033537  1.143293     NaN           179   NaN      NaN   damien
# 1    1.271341  1.435976     NaN           268   NaN      NaN   damien
# 2    1.984756   2.63872     NaN            89   NaN      NaN   damien
# 3        2.55      4.53     NaN            23   NaN      NaN   damien
# 4        1.16      1.27     NaN            29   NaN      NaN   damien
#
# [5 rows x 38 columns]
# ////////////////Info for Effect-sizes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15857 entries, 0 to 15856
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NUM                   13653 non-null  float64
#  1   ID                    15857 non-null  object
#  2   Figure                15857 non-null  object
#  3   Land_use              15857 non-null  object
#  4   Intervention          15857 non-null  object
#  5   Sub_Cat_intervention  15857 non-null  object
#  6   details               15855 non-null  object
#  7   Control (C)           15810 non-null  object
#  8   treatment_authors     14065 non-null  object
#  9   summary_effect_size   330 non-null    object
#  10  management            15573 non-null  object
#  11  method                15663 non-null  object
#  12  species               15515 non-null  object
#  13  region_climate        15804 non-null  object
#  14  soil                  15857 non-null  object
#  15  depth_original        15456 non-null  object
#  16  depth                 15395 non-null  object
#  17  group_depth           3120 non-null   object
#  18  depth2                13636 non-null  object
#  19  Duration              15816 non-null  object
#  20  carbon                15857 non-null  object
#  21  Inverse_ES            253 non-null    object
#  22  unit                  15698 non-null  object
#  23  Rateyr                15822 non-null  object
#  24  Log_scale             15857 non-null  object
#  25  metric                15857 non-null  object
#  26  Outcome               15857 non-null  object
#  27  Sub_cat_outcome       15857 non-null  object
#  28  details_outcome       15774 non-null  object
#  29  Homogenized_response  15857 non-null  object
#  30  lower_CI              15537 non-null  object
#  31  Effect size           15852 non-null  object
#  32  upper_CI              15542 non-null  object
#  33  p_value               3901 non-null   object
#  34  N_paired_data         14844 non-null  object
#  35  ES_SE                 4556 non-null   object
#  36  comments              6036 non-null   object
#  37  Reviewer              15857 non-null  object
# dtypes: float64(1), object(37)
# memory usage: 4.6+ MB
# ////////////////Description for Effect-sizes:
#                 NUM
# count  13653.000000
# mean    8887.804732
# std     4735.275098
# min        1.000000
# 25%     4626.000000
# 50%     9195.000000
# 75%    13254.000000
# max    15992.000000
# ////////////////First few rows of Primary_studies:
#                            ID  \
# 0     497_Barcena et al, 2014
# 1     497_Barcena et al, 2014
# 2     518_Poeplau et al, 2011
# 3         516_Shi et al, 2016
# 4  1006_Cardinael et al, 2018
#
#                                 Primary studies_name  \
# 0  Vesterdal L, Rosenqvist L, Salm C, Hansen K, G...
# 1  Vesterdal L, Rosenqvist L, Salm C, Hansen K, G...
# 2  Vesterdal L, Rosenqvist L, Salm C, Hansen K, G...
# 3  Kooch Y, Hosseini SM, Zaccone C, Jalilvand H, ...
# 4                             Nijmeijer et al., 2018
#
#                          DOI Primarystudies_Country Primarystudies_Region  \
# 0    10.1007/1-4020-4568-9_2                Denmark                   NaN
# 1    10.1007/1-4020-4568-9_2                 Sweden                   NaN
# 2    10.1007/1-4020-4568-9_2                Denmark                   NaN
# 3         10.1039/c2em30410d                   Iran            Mazandaran
# 4  10.1007/s10457-018-0204-z               Cameroon                   NaN
#
#   intervention            Outcome  \
# 0          LUC       Soil_carbon
# 1          LUC       Soil_carbon
# 2          LUC       Soil_carbon
# 3          LUC       Soil_carbon
# 4   LUC, Manag   Soil_chemistry,
#
#                                        Article Title Authors  \
# 0  Carbon Sequestration in Soil and Biomass Follo...     NaN
# 1  Carbon Sequestration in Soil and Biomass Follo...     NaN
# 2  Carbon Sequestration in Soil and Biomass Follo...     NaN
# 3  Soil organic carbon sequestration as affected ...     NaN
# 4  Correction to: Carbon dynamics in cocoa agrofo...     NaN
#
#   Author Full Names  ... Author Keywords Addresses Cited References  \
# 0               NaN  ...             NaN       NaN              NaN
# 1               NaN  ...             NaN       NaN              NaN
# 2               NaN  ...             NaN       NaN              NaN
# 3               NaN  ...             NaN       NaN              NaN
# 4               NaN  ...             NaN       NaN              NaN
#
#                   ISSN Journal Abbreviation Journal ISO Abbreviation  \
# 0                  NaN                  NaN                      NaN
# 1                  NaN                  NaN                      NaN
# 2                  NaN                  NaN                      NaN
# 3  1464-0325,1464-0333                  NaN                      NaN
# 4  0167-4366,1572-9680                  NaN                      NaN
#
#   Publication Year WoS Categories Research Areas Reviewer
# 0           2007.0            NaN            NaN   Julien
# 1           2007.0            NaN            NaN   Julien
# 2           2007.0            NaN            NaN   Damien
# 3           2012.0            NaN            NaN   Damien
# 4           2018.0            NaN            NaN     RÈmi
#
# [5 rows x 24 columns]
# ////////////////Info for Primary_studies:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22772 entries, 0 to 22771
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        22772 non-null  object
#  1   Primary studies_name      22754 non-null  object
#  2   DOI                       22769 non-null  object
#  3   Primarystudies_Country    21364 non-null  object
#  4   Primarystudies_Region     15660 non-null  object
#  5   intervention              12676 non-null  object
#  6   Outcome                   22762 non-null  object
#  7   Article Title             13252 non-null  object
#  8   Authors                   7438 non-null   object
#  9   Author Full Names         7439 non-null   object
#  10  Abstract                  7228 non-null   object
#  11  Source Title              7438 non-null   object
#  12  Language                  7438 non-null   object
#  13  Document Type             13545 non-null  object
#  14  Author Keywords           6019 non-null   object
#  15  Addresses                 7189 non-null   object
#  16  Cited References          7383 non-null   object
#  17  ISSN                      13464 non-null  object
#  18  Journal Abbreviation      7435 non-null   object
#  19  Journal ISO Abbreviation  7425 non-null   object
#  20  Publication Year          13536 non-null  float64
#  21  WoS Categories            7438 non-null   object
#  22  Research Areas            7438 non-null   object
#  23  Reviewer                  22611 non-null  object
# dtypes: float64(1), object(23)
# memory usage: 4.2+ MB
# ////////////////Description for Primary_studies:
#        Publication Year
# count      13536.000000
# mean        2007.247045
# std           25.281885
# min            8.000000
# 25%         2005.000000
# 50%         2009.000000
# 75%         2012.000000
# max         2020.000000

# %%
# sheet names to keep and save as files
sheets_to_keep = ['retained_meta-analyses', 'Effect-sizes', 'Primary_studies']

for sheet_name in xls.sheet_names:
    if sheet_name in sheets_to_keep:
        sheets_df[sheet_name] = pd.read_excel(xls, sheet_name=sheet_name)
        csv_path = os.path.join(paths['processed_data_path'], f"{sheet_name}.csv")
        sheets_df[sheet_name].to_csv(csv_path, index=False)
        print(f"{sheet_name} saved to {csv_path}")
# Out:
# retained_meta-analyses saved to /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/retained_meta-analyses.csv
# Effect-sizes saved to /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/Effect-sizes.csv
# Primary_studies saved to /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/Primary_studies.csv

# %% [markdown]
# ### ETL

# %%
#files per sheet
df_retained = load_data('retained_meta-analyses')
print(df_retained.columns)
print(df_retained.shape)

df_effects = load_data('Effect-sizes')
print(df_effects.columns)
print(df_effects.shape)


df_primary = load_data('Primary_studies')
print(df_primary.columns)
print(df_primary.shape)
# Out:
# Index(['ID', 'SOC_as_covariable', 'Quality_Unit',
#        'Quality_appraisal of primary studies', 'Quality_Lit_gray_and_peer',
#        'Quality_Lit_Nb_database', 'Quality_Lit_strings_OK',
#        'Quality_Lit_inclusion_exclusion', 'Quality_Model',
#        'Quality_Model_weights', 'Quality_Model_heterogeneity (I2, PI, …)',
#        'Quality_Publication_bias', 'soil_depth', 'length_time_series',
#        'Quality_Data_Sharing', 'Population: geographical scale',
#        'Field experiment', 'Lab, incubation, greenhouse', 'Other',
#        'Mitigation', 'Adaptation', 'FoodSecurity', 'Source', 'Article Title',
#        'Abstract', 'Keywords', 'Authors', 'Year', 'Journal', 'link',
#        'Keywords Plus', 'Addresses', 'Email Addresses', 'Funding Orgs',
#        'Cited Reference Count', 'Times Cited, WoS Core',
#        'Times Cited, All Databases', 'WoS Categories', 'Research Areas',
#        'reviewer'],
#       dtype='object')
# (217, 40)
# Index(['NUM', 'ID', 'Figure', 'Land_use', 'Intervention',
#        'Sub_Cat_intervention', 'details', 'Control (C)', 'treatment_authors',
#        'summary_effect_size', 'management', 'method', 'species',
#        'region_climate', 'soil', 'depth_original', 'depth', 'group_depth',
#        'depth2', 'Duration', 'carbon', 'Inverse_ES', 'unit', 'Rateyr',
#        'Log_scale', 'metric', 'Outcome', 'Sub_cat_outcome', 'details_outcome',
#        'Homogenized_response', 'lower_CI', 'Effect size', 'upper_CI',
#        'p_value', 'N_paired_data', 'ES_SE', 'comments', 'Reviewer'],
#       dtype='object')
# (15857, 38)
# Index(['ID', 'Primary studies_name', 'DOI', 'Primarystudies_Country',
#        'Primarystudies_Region', 'intervention', 'Outcome', 'Article Title',
#        'Authors', 'Author Full Names', 'Abstract', 'Source Title', 'Language',
#        'Document Type', 'Author Keywords', 'Addresses', 'Cited References',
#        'ISSN', 'Journal Abbreviation', 'Journal ISO Abbreviation',
#        'Publication Year', 'WoS Categories', 'Research Areas', 'Reviewer'],
#       dtype='object')
# (22772, 24)

# %%
# Columns to drop from each dataframe
columns_to_drop_df_retained = [
    'Quality_appraisal of primary studies', 'Quality_Lit_gray_and_peer',
    'Quality_Lit_Nb_database', 'Quality_Lit_strings_OK',
    'Quality_Lit_inclusion_exclusion', 'Quality_Model',
    'Quality_Model_weights', 'Quality_Model_heterogeneity (I2, PI, …)',
    'Lab, incubation, greenhouse', 'Other',
    'Mitigation', 'Adaptation', 'FoodSecurity', 'Source', 'Article Title',
    'Abstract', 'Keywords', 'Authors', 'Year', 'Journal', 'link',
    'Keywords Plus', 'Addresses', 'Email Addresses', 'Funding Orgs',
    'Cited Reference Count', 'Times Cited, WoS Core',
    'Times Cited, All Databases', 'WoS Categories', 'Research Areas',
    'reviewer'
]

columns_to_drop_df_effects = [
    'NUM', 'Figure', 'Inverse_ES', 'Homogenized_response', 'comments', 'Reviewer'
]

columns_to_drop_df_primary = [
    'Primary studies_name', 'Primarystudies_Region', 'Article Title',
    'Authors', 'Author Full Names', 'Abstract', 'Source Title', 'Language',
    'Document Type', 'Author Keywords', 'Addresses', 'Cited References',
    'ISSN', 'Journal Abbreviation', 'Journal ISO Abbreviation',
    'Publication Year', 'WoS Categories', 'Research Areas', 'Reviewer'
]


df_retained.drop(columns=columns_to_drop_df_retained, inplace=True)
print("Updated df_retained columns:", df_retained.info())

df_effects.drop(columns=columns_to_drop_df_effects, inplace=True)
print("Updated df_effects columns:", df_effects.info())

df_primary.drop(columns=columns_to_drop_df_primary, inplace=True)
print("Updated df_primary columns:", df_primary.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              217 non-null    object
#  1   SOC_as_covariable               217 non-null    object
#  2   Quality_Unit                    199 non-null    object
#  3   Quality_Publication_bias        217 non-null    object
#  4   soil_depth                      217 non-null    object
#  5   length_time_series              215 non-null    object
#  6   Quality_Data_Sharing            217 non-null    object
#  7   Population: geographical scale  201 non-null    object
#  8   Field experiment                217 non-null    object
# dtypes: object(9)
# memory usage: 15.4+ KB
# Updated df_retained columns: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15857 entries, 0 to 15856
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    15857 non-null  object
#  1   Land_use              15857 non-null  object
#  2   Intervention          15857 non-null  object
#  3   Sub_Cat_intervention  15857 non-null  object
#  4   details               15855 non-null  object
#  5   Control (C)           15810 non-null  object
#  6   treatment_authors     14065 non-null  object
#  7   summary_effect_size   330 non-null    object
#  8   management            15573 non-null  object
#  9   method                15663 non-null  object
#  10  species               15515 non-null  object
#  11  region_climate        15804 non-null  object
#  12  soil                  15857 non-null  object
#  13  depth_original        15456 non-null  object
#  14  depth                 15395 non-null  object
#  15  group_depth           3120 non-null   object
#  16  depth2                13636 non-null  object
#  17  Duration              15816 non-null  object
#  18  carbon                15857 non-null  object
#  19  unit                  15698 non-null  object
#  20  Rateyr                15822 non-null  object
#  21  Log_scale             15857 non-null  object
#  22  metric                15857 non-null  object
#  23  Outcome               15857 non-null  object
#  24  Sub_cat_outcome       15857 non-null  object
#  25  details_outcome       15774 non-null  object
#  26  lower_CI              15537 non-null  object
#  27  Effect size           15852 non-null  object
#  28  upper_CI              15542 non-null  object
#  29  p_value               3901 non-null   object
#  30  N_paired_data         14844 non-null  object
#  31  ES_SE                 4556 non-null   object
# dtypes: object(32)
# memory usage: 3.9+ MB
# Updated df_effects columns: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22772 entries, 0 to 22771
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      22772 non-null  object
#  1   DOI                     22769 non-null  object
#  2   Primarystudies_Country  21364 non-null  object
#  3   intervention            12676 non-null  object
#  4   Outcome                 22762 non-null  object
# dtypes: object(5)
# memory usage: 889.7+ KB
# Updated df_primary columns: None

# %%
# Columns for which to find unique elements
unique_columns_df_retained = ['SOC_as_covariable', 'Quality_Unit',
       'soil_depth', 'length_time_series',
        'Field experiment']
unique_columns_df_effects = ['Land_use', 'Intervention', 'Sub_Cat_intervention', 'details',
       'Control (C)', 'treatment_authors', 'management',
       'method', 'species', 'region_climate', 'soil', 'depth_original',
       'depth', 'group_depth', 'depth2', 'Duration', 'carbon', 'unit',
       'Rateyr', 'Log_scale', 'metric', 'Outcome', 'Sub_cat_outcome',
       'details_outcome',
       'N_paired_data']
unique_columns_df_primary = ['Primarystudies_Country', 'intervention', 'Outcome']

print("//////////////////Unique values for df_retained:")
print_unique_values(df_retained, unique_columns_df_retained)

print("//////////////////Unique values for df_effects:")
print_unique_values(df_effects, unique_columns_df_effects)

print("//////////////////Unique values for df_primary:")
print_unique_values(df_primary, unique_columns_df_primary)
# Out:
# //////////////////Unique values for df_retained:
# Unique values in SOC_as_covariable: ['YES' 'NO']
# Total unique in SOC_as_covariable: 2
# Unique values in Quality_Unit: [nan 'YES, MM' 'NO' 'YES, Results' 'Yes, MM' 'YES, supMat' 'YES, others']
# Total unique in Quality_Unit: 7
# Unique values in soil_depth: ['not analysed/detailed' 'yes, subgroups according to soil depth'
#  'mixed different layers/all regrouped' 'yes, regression'
#  'aggregated/normalized/restricted to 0-15 cm'
#  'aggregated/normalized/restricted to 3-100 cm'
#  'aggregated/normalized/restricted to 7-30 cm'
#  'aggregated/normalized/restricted to 0-20 cm'
#  'aggregated/normalized/restricted to 0-30 cm' 'all > 30cm'
#  'aggregated/normalized/restricted to 0-100 cm'
#  'aggregated/normalized/restricted to 15-30 cm' 'considered in the model'
#  'yes, up to > 100 cm' 'only the uppermost layer' 'yes, up to > 30 cm'
#  'aggregated/normalized/restricted to 0-50 cm' 'averaged depth'
#  'yes, up to 40cm']
# Total unique in soil_depth: 19
# Unique values in length_time_series: ['not analysed/detailed' 'yes, regression' 'test, per group of duration'
#  'yes' 'all  grouped' nan 'yes, in the model' 'long term experiments'
#  'mini 30 years']
# Total unique in length_time_series: 9
# Unique values in Field experiment: ['YES' '-']
# Total unique in Field experiment: 2
# //////////////////Unique values for df_effects:
# Unique values in Land_use: [' cropland' ' forest land' 'Land_use change' 'cropland' 'grassland'
#  ' Cropland' 'Grassland' ' various land uses' ' grassland' 'shrublands'
#  'Cropland' 'Desert' 'Shrublands' 'Tundra' ' wetlands' 'wetlands'
#  'forest land' 'heatland' 'tundra' ' other land : various'
#  'various land uses' 'Grassland ' 'Heatland' 'Forest land'
#  'Various land uses' ' other land' ' Forest land']
# Total unique in Land_use: 27
# Unique values in Intervention: ['management ' 'global changes ' 'global changes/management '
#  'land use change' 'land use change/management '
#  'Global changes/management ' 'global changes' 'management' 'Others']
# Total unique in Intervention: 9
# Unique values in Sub_Cat_intervention: ['amendments pyrogenic' 'Prescribed Fire' 'Wild Fire' 'Fire' 'cover crops'
#  'other land -> forest land' 'agroforestry' 'forest land -> cropland'
#  'grassland -> cropland' 'forest land -> grassland'
#  'cropland -> grassland' 'Agroforestry' 'forest land -> various land uses'
#  'other land -> cropland' 'other land -> various land uses'
#  'other land -> grassland' 'Fire ; forest harvesting'
#  'fire ; forest harvesting' 'forest harvesting'
#  'mineral fertilization type' 'grazing' 'residues management'
#  'various land uses -> various land uses'
#  'amendments pyrogenic ; fertilization' 'mineral fertilization'
#  'amendments non-pyrogenic substitution' 'amendments non-pyrogenic'
#  'crop rotation' 'Amendments non-pyrogenic ; residues management'
#  'Amendments non-pyrogenic substitution' 'Amendments non-pyrogenic'
#  'Tillage ; residues management ; cover crops'
#  'Amendments non-pyrogenic ; mineral fertilization' 'organic farming'
#  'tillage' 'amendments non-pyrogenic ; cover crops' 'grazing type'
#  'climate change : drought/rainfall reduction'
#  'drought/rainfall reduction' 'freeze-thaw ; snow cover'
#  'climate change : warming' 'CO2 enrichment'
#  'CO2 enrichment ; fertilization ' 'climate change : CO2 enrichment'
#  'CO2 enrichment, fertilization' 'CO2 enrichment ; mineral fertilization'
#  'woodlands' 'woodlots' 'various land uses -> cropland'
#  'various land uses -> grassland' 'Other' 'cropland -> various land uses'
#  'Other land -> cropland' 'warming experiments'
#  'cover crops ; crop rotation'
#  'mineral fertilization ; residues management'
#  'amendments non-pyrogenic ; mineral fertilization' 'biotic disturbance'
#  'Mineral fertilization ; grazing ; Liming' 'liming' 'water management'
#  'cropland -> other land' 'grassland -> other land'
#  'cropland -> forest land' 'various land uses -> forest land'
#  'grassland -> forest land'
#  'Amendments non-pyrogenic ; cover crops ; Water management ; crop rotation'
#  'Tillage' 'forest land -> other land' 'forest degradation'
#  'forest land -> various land' 'Forest degradation'
#  'forest land -> wetlands' 'energy crop' 'conifer vs. hardwood stands'
#  'other land -> other land' 'wetlands -> cropland' 'grassland -> wetlands'
#  'wetland degradation' 'residues management ; tillage'
#  'litterfall removal' 'litter removal' 'plastic film mulching'
#  'residue : retention ; Tillage' 'tillage '
#  'amendments : slurry ; cover crops' 'cover crops ; mineral fertilization'
#  'amendments : manure ; cover crops' 'cover crops ; mineral fertilizer'
#  'cover crops ; tillage' 'genotype/Species selection'
#  'soil acidification ; soil pollution' 'combination of climatic factors'
#  'degradation' 'forest harvesting type' 'Combination of climatic factors'
#  'drought/rainfall reduction ; mineral fertilization'
#  'warming experiments ; mineral fertilization' 'grazing, seeding'
#  'Species mixtures']
# Total unique in Sub_Cat_intervention: 100
# Unique values in details: ['amendments : biochar' 'fire : prescribed' 'fire : Wildfire'
#  'fire : all types/non-precised' 'cover crops : annual crops'
#  'other land -> forest land' 'agroforestry : sequential : fallows'
#  'agroforestry : simultaneous : alley cropping/silvoarable'
#  'agroforestry : simultaneous : hedgerows'
#  'agroforestry : simultaneous : multistrata systems'
#  'agroforestry : simultaneous : parklands'
#  'agroforestry : simultaneous : shaded perennial-crop'
#  'agroforestry : simultaneous : silvopasture'
#  'Agroforestry : sequential : fallows' 'agroforestry : various'
#  'Agroforestry : sequential : woodlots'
#  'Agroforestry : simultaneous : alley cropping/silvoarable'
#  'Agroforestry : simultaneous : hegerows'
#  'Agroforestry : simultaneous : multistrata systems'
#  'Agroforestry : simultaneous : parklands'
#  'Agroforestry : simultaneous : shaded perennial systems'
#  'agroforestry : simultaneous : agrosilvopasture/silvoarable/silvopasture'
#  'agroforestry : simultaneous : silvoarable'
#  'forest land -> cropland/grassland' 'other land -> cropland'
#  'forest land -> cropland' 'grassland -> cropland'
#  'agroforestry : simultaneous : agrosilvopasture'
#  'forest land -> grassland'
#  'agroforestry : simultaneous : silvoarable/silvopasture'
#  'other land -> cropland/grassland' 'cropland -> grassland'
#  'other land -> grassland'
#  'Fire : prescribed ; forest harvesting; type: all; intensity: all; residue management: all'
#  'Fire : prescribed + no wildfire ; forest harvesting; type: all; intensity: all; residue management: all'
#  'Fire : prescribed + wildfire ; forest harvesting; type: all; intensity: all; residue management: all'
#  'forest harvesting; type: all; intensity: all; residue management: all'
#  'fertilization : N' 'grazing : intensity : exclusion'
#  'residue : retention'
#  'forest harvesting; type: all; intensity: all; residue management: removed'
#  'forest harvesting; type: all; intensity: logs only; residue management: all'
#  'fire :  prescribed/wildfire' 'various land -> various land'
#  'amendments : biochar ; fertilization N' 'fertilization : NPK'
#  'amendments : manure' 'amendments : Manure ; fertilization : N'
#  'amendments : all' 'crop rotation : all crops' 'Organic amendments : all'
#  'Organic amendments : straw' nan 'amendments : compost'
#  'amendments : mulch' 'amendments : green manure ; residue : retention'
#  'amendments : green manure/manure ; residue : retention'
#  'amendments : biosolid/biowaste/green manure/manure'
#  'amendments : biosolid' 'amendments : biowaste' 'amendments : straw'
#  'amendments : green manure'
#  'amendments : all ; cover crops ; tillage : reduced/ no-till ; residue : retention'
#  'cover crops : orchards' 'cover crops : orchards/vineyards'
#  'cover crops : vineyards'
#  'amendments : compost/green manure/manure ; fertilization : N ; residue : retention'
#  'amendments : compost/green manure/manure ; residue : retention'
#  'organic agriculture' 'amendments : all/various' 'amendments : slurry'
#  'cover crops : all' 'fertilization : none' 'tillage : no-till'
#  'tillage : reduced'
#  'amendments : all ; cover crops ; tillage : reduced ; residue : retention '
#  'amendments : wastes' 'amendments : compost ; cover crops'
#  'amendments : manure ; cover crops' 'grazing : intensity : all'
#  'grazing : intensity : heavy' 'grazing : intensity : light'
#  'grazing : intensity : moderate'
#  'grazing : intensity : all ; animals : cattle'
#  'grazing : intensity : all ; animals : sheep'
#  'grazing : intensity : heavy ; animals : cattle'
#  'grazing : intensity : heavy ; animals : sheep'
#  'grazing : intensity : light ; animals : cattle'
#  'grazing : intensity : light ; animals : sheep'
#  'grazing : intensity : moderate ; animals : cattle'
#  'grazing : intensity : moderate ; animals : sheep'
#  'grazing : intensity : extreme' 'grazing : continuous'
#  'grazing : rotational' 'grazing : intensity : all ; animals : mixed'
#  'grazing : intensity : all ; animals : all'
#  'climate change : drought/rainfall reduction'
#  'drought/rainfall reduction' 'freeze-thaw ; snow cover'
#  'climate change : warming' 'CO2 enrichment'
#  'CO2 enrichment ; fertilization ' 'climate change : CO2 enrichment'
#  'CO2 enrichment, fertilization' 'snow cover'
#  'climate change : CO2 ; fertilization : N'
#  'climate change : CO2 ; fertilization : NPK'
#  'agroforestry : simultaneous : agrisilviculture'
#  'agroforestry : boundary planting/hedgerow'
#  'agroforestry : sequential : woodlots' 'cropland -> forest land'
#  'Agroforestry : simultaneous : homegarden' 'woodlots'
#  'Agroforestry : simultaneous : silvopasture'
#  'cropland/grassland -> cropland' 'forest land/grassland -> cropland'
#  'cropland/forest land -> cropland'
#  'cropland/forest land/grassland -> cropland'
#  'cropland/forest land/grassland/other land -> cropland'
#  'cropland/grassland/other land -> grassland'
#  'forest land/grassland -> grassland' 'protective systems'
#  'agroforestry : simultaneous : all'
#  'Cropland/forest land/grassland -> cropland'
#  'Cropland/Forest land/grassland -> cropland'
#  'Cropland/Forest land -> cropland' 'Forest land/grassland -> cropland'
#  'Other land -> cropland' 'Cropland/grassland -> cropland'
#  'Cropland/grassland/other land -> cropland'
#  'Cropland/Forest land/grassland/other land -> cropland'
#  'fertilization : NP' 'fertilization : P'
#  'cover crops ; crop rotation : annual/perennial : all crops'
#  'rotation : annual/perennial : all crops'
#  'cover crops ; crop rotation : perennial : all crops'
#  'rotation : annual : legume-based'
#  'agroforestry : simultaneous : hedgerows ; grass field margins'
#  'grass field margins' 'organic farming'
#  'amendments : all ; fertilization : NPK' 'amendments : ash'
#  'fire : wildfire' 'fertilization : NPK : residue : straw'
#  'fertilization : NK' 'fertilization : PK'
#  'fertilization : NPK ;  amendments : manure' 'fertilization : K'
#  'amendments : compost/manure' 'fertilization : NPK ; residue : retention'
#  'earthworms abundance' 'fertilization : Se'
#  'amendments : compost/green manure/manure ; fertilization : all'
#  'amendments : manure ; fertilization : NPK'
#  'amendments : manure ; fertilization : N'
#  'amendments : manure ; fertilization : NP' 'fertilization : NPKS'
#  'fertilization : NPS' 'fertilization : NS' 'fertilization : S'
#  'amendments : all ; fertilization : N'
#  'fertilization : NPK ; grazing : intensity : all : animals : all ; liming'
#  'amendments : liming' 'water management : irrigation'
#  'water managment : irrigation' 'cropland -> other land'
#  'grassland -> other land' 'tillage : no-till/reduced' 'afforestation'
#  'cropland/grassland/other land -> forest land' 'grassland -> forest land'
#  'cropland/grassland/other land/settlements-> forest land'
#  'other land/settlements -> forest land'
#  'cropland/grassland -> forest land' 'grassland/other land -> forest land'
#  'amendments : all ; cover crops ; irrigation ; residue : retention ; rotation : annual/perennial'
#  'amendments : green manure ; cover crops ; residue : retention'
#  'residue : no retention ; rotation : annual'
#  'cropland/forest land/grassland/other land -> cropland/forest land/grassland/other land'
#  'plantation' 'forest land -> other land' 'woodland -> plantation'
#  'cropland -> forest land/grassland'
#  'forest land/grassland/other land -> forest land'
#  'forest land -> cropland/forest land'
#  'forest land -> cropland/forest land/grassland'
#  'primary forest -> cropland' 'primary forest -> grassland'
#  'primary forest -> perennial cropland' 'primary forest -> plantation'
#  'primary forest -> secondary forest' 'secondary forest -> cropland'
#  'secondary forest -> grassland' 'secondary forest -> plantation'
#  'forest harvesting; type: clear-cutting/thinning; intensity: stem-only; residue management: all'
#  'forest harvesting; type: clear-cutting/thinning; intensity: stem-only/whole-tree; residue management: all'
#  'forest harvesting; type: clear-cutting/thinning; intensity: stem-only/whole-tree; residue management: fire'
#  'forest harvesting; type: clear-cutting/thinning; intensity: whole-tree; residue management: all'
#  'forest harvesting; type: thinning; intensity: stem-only/whole-tree; residue management: all'
#  'primary forest/secondary forest -> plantation'
#  'rotation : annual/perennial : legume-based' 'tillage : intensive'
#  'forest land -> cropland/grassland/other land/wetlands'
#  'forest land -> wetlands' 'crop to plantation'
#  'cropland/forest land/grassland -> cropland/forest land/grassland'
#  'energy crop : perennial grasses' 'energy crop : short rotation coppice'
#  'genotype/species/cultivar'
#  'cropland/forest land -> cropland/forest land'
#  'Natural forest -> plantation' 'tree species' 'other land -> other land'
#  'cropland -> forest land/grassland/other land'
#  'cropland/forest land/grassland/other land -> forest land/grassland/other land'
#  'forest land/grassland/other land -> forest land/grassland/other land'
#  'no management' 'plantation -> secondary forest' 'wetlands -> cropland'
#  'grassland -> wetlands' 'wetland restauration'
#  'woody plant encroachment removal'
#  'agroforestry : all ; cover crops ; cropland -> forest land ; fertilization : all ; rotation : all'
#  'landscaping : stone bunds'
#  'landscaping : stone bunds ; biological intervention'
#  'landscaping : terracing'
#  'residue : retention ; rotation : annual : all crops ; tillage : no-till'
#  'amendments : compost/green manure/manure/slurry ; residue : retention'
#  'residue : no retention ; tillage : no-till'
#  'residue : retention ; tillage : no-till'
#  'aboveground biomass : exportation'
#  'aboveground biomass : no exportation' 'litter : no retention'
#  'litter : retention' 'crop-livestock production'
#  'forest land/other land -> cropland' 'plastic film mulching'
#  'amendments : manure ; residue : retention ; tillage : reduced/no-till'
#  'tillage : reduced/no-till' 'residue : no retention'
#  'amendments : slurry ; cover crops : annual crops'
#  'amendments : manure ; cover crops : annual crops'
#  'cover crops : annual crops ; mineral fertilizer'
#  'fertilization : reduced' 'rotation : perennial/annual : all crops'
#  'cover crops ; tillage: no-till' 'pollution' 'Shrub-encroached grassland'
#  'soil acidification' 'canopy vs. inter-canopy' 'biotic disturbance'
#  'climate change : CO2 ; warming' 'degradation'
#  'cover crops ; tillage: reduced/no-till'
#  'forest harvesting; type: clear-cutting; intensity: whole-tree; residue management: all'
#  'forest harvesting; type: clear-cutting; intensity: stem-only; residue management: all'
#  'forest harvesting; type: thinning; intensity: stem-only; residue management: all'
#  'cropland/other land -> forest land'
#  'climate change : CO2 ; drought/rainfall'
#  'climate change : drought/rainfall ; fertilization : N'
#  'climate change : drought/rainfall ; warming'
#  'climate change : warming ; fertilization : N' 'mineral fertilization'
#  'forest harvesting; type: all; intensity: stem-only; residue management: all'
#  'water management : paddy fields : mid-season aeration with single drainage or intermittent irrigation with multiple drainage'
#  'water management : paddy fields : mid-season aeration with single drainage'
#  'water management : paddy fields : intermittent irrigation with multiple drainage - the field is kept waterlogged after drainage'
#  'water management : paddy fields : intermittent irrigation with multiple drainage - the field is kept moist after drainage'
#  'amendments : green manure/manure ; fertilization : NPK'
#  'amendments : biogas residue ; fertilization : NPK'
#  'integrated farming : paddy fields' 'crop mixture' 'intercropping'
#  'species mixture' 'agroforestry : sequential : all']
# Total unique in details: 275
# Unique values in Control (C): ['No biochar' 'No fire' 'no cover crops' 'farmland or abandonned land' nan
#  'other land' 'Cropland (previous land use)' 'Forest (previous land use)'
#  'Grassland (previous land use)' 'Plantation (previous land use)'
#  'non fertilized control' 'Fertilized control' 'unfertilized cntrol' '-'
#  '1' 'Pasture/Grassland (previous land use)' 'All previous land use'
#  'Agriculture (previous land use)'
#  'Uncultivated/Other (previous land use)'
#  'Forest plantation (previous land use)' 'no fire' 'no fire, no harvest'
#  'no harvest' 'Urea' 'other grazing practices ' 'no amendments'
#  'no residues  amendments' 'various land' 'no ferti'
#  'synthetic fertilizer only' 'Without fresh C input' 'Grassland'
#  'no fertilizer added' 'simplified rotation' 'mineral only fertilization'
#  'no organic material added' 'No organic amendments'
#  'Inorganic fertilizer' 'no fertilization' 'mineral fertilization'
#  'conventional management (no C input)' 'conventional management'
#  'Synthetic N' 'Straw removal' 'straw removal' 'no straw retention'
#  'No straw return' 'No N fertilization' 'Organic amendment'
#  'No input at all' 'N fertilizer'
#  'Conventional management (synthetic fertil- ization, conventional tillage and non-use of organic inputs, except crop residues in some cases)'
#  'No grazing' 'no grazing exclusion' 'NO grazing' 'continous grazing'
#  'no grazing' 'No Drougth' 'No Irrigation' 'no drought' 'no irrigation'
#  'no Drougth' 'no Irrigation' 'non freeze-thaw' 'no watering' 'no warming'
#  'no wetting effect' 'No CO2 enrichment' 'no elevated C02'
#  'no CO2 enrichment' 'No warming' 'ALL' 'no N added' 'non-warming'
#  'no snow manipulation' 'No rainfall reduction'
#  'No C02 elevation and  noN ferti' 'no C02 elevation' 'no N ferti'
#  'before-after' 'Previous land-use' 'Cropland' 'Degraded fallow'
#  'cropland' 'CRopland' 'unshaded system' 'grassland' 'underutilsed land'
#  'fallow land' 'Fallow' 'Unshaded' 'Underutilized'
#  'Sole cropping, continuous cropping without trees, and plots outside tree crowns in the case of parklands'
#  'tillage : conventional' 'pasture'
#  'Forest or agricultural land use or pasture' 'Agriculture land' 'Forest'
#  'Pasture' 'PAsture' 'Uncultivated land' 'Agrisilviculture'
#  'Cropland/forest land/grassland to Trop_Agrosilvopasture  ('
#  'Forest or agricultural land use or pasture or unultivated'
#  'grassland/other land to Trop_Silvopasture'
#  'Forest or agricultural land use'
#  'Grassland_other land to Trop_Agrisilvopasture  '
#  'cropland->Multistrata systems'
#  'Cropland/forest to Temp_Agrisilviculture '
#  'Forest/pasture  to Temp_Silvopasture '
#  'Other land to Temp_Agrosilvopasture '
#  'cropland/grassland to Arid_Agrisilviculture '
#  'Cropland/grassland/other land to Trop_Agrisilviculture ('
#  'cropland/forest to Trop_Agrisilviculture '
#  'Forest land/grassland  to Trop_Agrosilvopasture '
#  'cropland/forest land/grassland to Silvopasture'
#  'cropland/forest land/grassland/other lands to Agrisilviculture'
#  'Forest land/grassland to Silvopasture' 'bare fallow' 'NO cover crops'
#  'No temperature increase' 'No precipitation increase'
#  'No precipitation reduction' 'No NP fertilization' 'No P fertilization'
#  'Monoculture' 'rotation with lower fonctional richness'
#  'non agroforestry' 'Cropland or pasture' 'no hedgrow' 'no grass strips'
#  'conventional agriculture ' 'Clean tillage' 'No fertilization'
#  'non N addition' 'no N addition' 'no ash application' 'No N addition'
#  'unfertilized' 'Non N addition' 'Without earthworms' 'no P'
#  'no Se fertilization' 'Organic fertilizer (initial stage)'
#  'Combined chemical + organic fertilizer (initial stage)'
#  'No fertilizer (initial stage)' 'Chemical fertilizer (initial stage)'
#  'no Straw return (initial stage)' 'no retention' 'no manure noferti'
#  'no manure ' 'no manure , no ferti' 'no manure' 'no manure, no ferti'
#  '100% inorganic N addition' 'No inorganic N addition'
#  'One shot inorganic N addition' 'Top placement of inorganic N addition'
#  'Normal inorganic N addition' 'no liming' 'no P addition'
#  'no fertilizer, liming and grazing' 'NO P addition' 'No liming'
#  'No irrigation' 'Continuous flooding' 'Young ex arable' 'Arable'
#  'Ancient grassland' 'conventional till' 'non afforested' 'Agricultural'
#  'agriculture cumtivated' 'agriculture unknown' 'all land use'
#  'agriculture forage' 'Wildland' 'Industrial'
#  'Agriculture (Cropland + Pasture) (previous land use)'
#  'Pasture (previous land use)' 'Natural grassland (previous land use)'
#  'former land use - cropland' 'no afforestation'
#  'former land use - grassland' 'former land use - heathland'
#  'former land use - barrenland' 'Natural grassland'
#  'No afforestation (previous land use)' 'non forested land'
#  'Initial SOC stock' 'Cropland/pasture/bare area' 'Bare area'
#  'No afforestation' 'medium C input' 'conventional practices' 'Native'
#  'other land use' 'Cultivated land' 'Wood land' 'Shrubland'
#  'natural vegetation' 'Primary forest' 'secondary Forest'
#  'Secondary Forest' 'Forest all' 'No forest harvesting'
#  'Grassland or Pasture' 'Grassland or pasture' 'Barren Land' 'Baren land '
#  'Primary or secondary forest' 'Grassland and Cropland' 'Continuous maize'
#  'No fertilizer' 'No-tillage ' 'Undisturbed mangrove (previous land use)'
#  'Crop' 'Overall' 'Crop (previous land use)' 'Savanna (previous land use)'
#  'Farmland (previous land use)' 'All previous land uses'
#  'Primary forest (previous land use)'
#  'Secondary forest (previous land use)' 'Arable land' 'Forest land'
#  'forest' 'Perennial plantation (previous land use)'
#  'Native forest (previous land use)' 'long fallow swidden' 'Uncut control'
#  'Natural forest' 'Grazed grassland (previous land use)'
#  'pure stand norway spruce' 'Shrub encroachment' 'Non-crop land'
#  'Plantation' 'Wetland' 'control wetland within 10km, or before-after'
#  'Previous land: forest' 'Grass' 'Previous land: Grass' 'natural Wetland'
#  'Woody plants retained' 'before biological intervention'
#  'Before exclosure' 'Before bunds'
#  'before bunds and biological intervention' 'before terrassing'
#  'Before conservation agriculture' 'No improved management practice'
#  'No organic manure' 'Mineral fertilizer' 'Conventional tillage'
#  'No organic matter input' 'Conventional agriculture' 'no CO2 change'
#  'no fetilizer' 'no till' 'residue removal' 'residue removed'
#  'High intensity tillage (e.g. mouldboard plough and subsoiling)'
#  'Intermediate tillage (e.g. chisel, disk, harrow and mulch plough)'
#  'chemical fertilization application' 'plow tillage with residue removal'
#  'no litter removal' 'no litter addition' 'no litter Exclusion'
#  'no litter excluision' 'Plow tillage + residue removed'
#  'Plow tillage + residue retention' 'No-tillage (previous land-use)'
#  'Savannah/forest' 'Savannah' 'Full tillage' 'Conventional farming'
#  'conventional farming' 'No plastic film' 'no organic C addition'
#  'before after' 'non removal' 'crop frequency: single (1 crop per year)'
#  'High intensity tillage' 'intermediate intensity tillage'
#  'conventional tillage without residues' 'Tillage' 'tillage'
#  'conventionnal tillage' 'Mineral fertilization' 'bare soil'
#  'no amendemenrts' 'traditional tillage + no cover crop'
#  'traditional tillage' 'NO Biochar' 'no high biomass rice cultivar'
#  'Non polluted soils' 'no pollution' 'no biochar'
#  'Non shrub-encroached grassland' 'No acid addition'
#  'Intercanopy microsite' 'no biotic disturbance' 'no CO2, no warming'
#  'no CO2' 'no precipitation increase' 'Nondegraded alpine meadow'
#  'No cover crops' 'Conventional forest harvest (tree stems)'
#  'Unharvested forests' 'Barren land' 'Natural sucession'
#  'non harvested + chronosequence' 'no C02 + Drought' 'no CO2 + drought'
#  'no CO2 + rainfall' 'no CO2+N' 'no cO2 + N' 'no C02+N' 'no CO2 + warming'
#  'no CO2+ Warming' 'no C02 + Warming' 'no C02+ Warming' 'no N + drougth'
#  'no N+ rainfall' 'no N+ P addition' 'no N +rainfall'
#  'no Warming + drougth' 'no Warming + Rainfall' 'no increase in rainfall'
#  'no Warming' 'no Warming + N' 'no Warming +N' 'no Rainfall' 'no N'
#  'no N+P addition' 'Non plant invasion' 'Non overgrazing'
#  'Whole tree harvest' 'no thinning' 'conifer stands ' 'Non treated urea'
#  'Degraded grassland' 'Urea (> 200 kg N ha-1)' 'Normal N fertilizer'
#  'no straw' 'NPK fertilizer' 'Rice only' 'N fertilizer (294 kg N ha-1)'
#  'N fertilizer (320 kg N ha-1)' 'N fertilizer (264 kg N ha-1)'
#  'N fertilizer (268 kg N ha-1)' 'Grazing' 'Heavy grazing'
#  'without crop mixture' 'no intercropping'
#  'No earthworms or reduced earthworm abundance ' 'monoculture plots']
# Total unique in Control (C): 357
# Unique values in treatment_authors: ['Biochar' 'PyC:Ratio >2' nan 'farmland or abandonned land->forested'
#  'farmland or abandoned land->forested'
#  'Land Use Change - Cropland to Fallow' 'Forest to Intercropping'
#  'Forest to Silvoarable' 'Land Use Change - Cropland to Silvoarable'
#  'Land Use Change - Cropland to Intercropping' 'Grassland to Hedgerow'
#  'Land Use Change - Cropland to Hedgerow' 'Forest to Multistrata'
#  'Land Use Change - Cropland to Multistrata' 'Grassland to Parkland'
#  'Forest to Parkland' 'Grassland to Shaded perennial'
#  'Forest to Shaded perennial' 'Plantation to Shaded perennial'
#  'Forest to Silvopasture' 'Grassland to Silvopasture'
#  'Land Use Change - Cropland to Silvopasture' 'biochar addition' 'fallows'
#  'miscellaneous' 'Woodlots' 'alley cropping/silvoarable' 'hedgerows'
#  'multistrata systems' 'parklands' 'shaded perennial-crop' 'silvopastures'
#  'grassland->agroforestry' 'all previous land uses->overall'
#  'cropland->agroforestry' 'cropland->Agrisilviculture'
#  'forested->agroforestry' 'uncultivated/other-> silvoarable'
#  'pasture/grassland->agroforestry' 'uncultivated/other->agroforestry'
#  'cropland->Agrosilvopastoral' 'grassland -> silvopasture'
#  'forest forested->agroforestry' 'all previous land use->agroforestry'
#  'prescribed fire' 'Thinning and fire' 'treaments' 'Thinning'
#  'Controlled release urea' 'grazing exclusion ' 'detail' 'YES'
#  'ferti added to control and treatment' 'Ferti  ' 'Biochar ' 'biochar '
#  'Replace synthetic fertilizers by animal manures'
#  'with fresh C input - Forest' 'with fresh C input'
#  'with fresh C input - Grassland' 'C input- Grassland' 'Organic amendment'
#  'Crop rotation' 'organic amendments' 'Organic input' 'Organic input '
#  'Organic input type - Plant residue' 'Organic inputs'
#  'Organic amendment: biosolid' 'Organic amendment: biowaste'
#  'Organic amendment : green manure'
#  'Organic amendment : Green manure and straw' 'Organic amendment : manure'
#  'Manure instead of Synthetic ferti' 'straw incorporation' 'Straw return'
#  'Straw retention' 'N fertilization'
#  'N fertilization Ecosystem - grassland'
#  'N fertilization - Ecosystem - forest'
#  'N fertilization - Ecosystem - shrubland'
#  'N fertilization - Ecosystem - farmland'
#  'Organic amendment + N fertilizer'
#  'Residual effect of Organic amendment + N fertilizer'
#  'Residual effect of Organic amendment' 'N fertilizer'
#  'Organic management'
#  'Land treatment (Organic inputs at >10 Mg C ha−1 yr−1 or municipal solid waste/sewage sludge at any rate)'
#  'Organic amendments (External inputs applied at <10 Mg C ha−1 yr−1)'
#  'Reduced tillage (none or crop residues)'
#  'Combined management practices (organic amendments with cover crops, crop residues, reduced tillage or no tillage)'
#  'Slurry'
#  'land treatment (organic inputs at >10 mg c ha−1 yr−1 or municipal solid waste/sewage sludge at any rate)'
#  'organic managment' 'No tillage (none or crop residues)' 'Heavy grazing'
#  'Light grazing' 'Moderate grazing' 'KEEP' 'Heavy grazing - C3 plants'
#  'Heavy grazing - C4 plants' 'Heavy grazing - Mixed C3 and C4 plants'
#  'Light grazing - C3 plants' 'Light grazing - C4 plants'
#  'Light grazing - Mixed C3 and C4 plants' 'Moderate grazing - C3 plants'
#  'Moderate grazing - C4 plants'
#  'Moderate grazing - Mixed C3 and C4 plants'
#  'Grazing intensity - Heavy grazing' 'Grazing intensity - Heavy grazing '
#  'Grazing intensity - Light grazing' 'Grazing intensity - Light grazing '
#  'Grazing intensity - Moderate grazing'
#  'Grazing intensity - Moderate grazing ' 'Grazing intensity - moderate'
#  'Grazing intensity - heavy' 'Grazing intensity - light'
#  ' Grazing intensity - heavy' '-' 'Cattle grazing' 'Sheep grazing'
#  'Cattle grazing / Grazing intensity - heavy'
#  'Sheep grazing / Grazing intensity - heavy' ' Grazing intensity - light'
#  'Cattle grazing / Grazing intensity - light'
#  'Sheep grazing / Grazing intensity - light'
#  ' Grazing intensity - moderate'
#  'Cattle grazing / Grazing intensity - moderate'
#  'Sheep grazing / Grazing intensity - moderate' 'grazing exclusion'
#  'Grazing intensity - over' ' Grazing intensity - high'
#  'Grazing intensity - high' 'Grazing intensity - low'
#  ' Grazing intensity - low' ' Grazing intensity - medium'
#  'Grazing intensity - medium' 'intensity : heavy' 'intensity : moderate'
#  'intensity : light' 'Grazing season - Annual grazing'
#  'Grazing season - Growing season grazing'
#  'Grazing season - Non growing season grazing'
#  'Livestock species - Cattle' 'Livestock species - Mixed sheep and cattle'
#  'Livestock species - Sheep' 'Grazing intensity - Extreme'
#  'Grazing intensity - Heavy' 'Grazing intensity - Light'
#  'Grazing intensity - Moderate' 'Forbs' 'graminoids' 'All animals'
#  'Cattle ' 'Sheep' 'Drougth- desert' 'Irrigation- desert' 'Drougth'
#  'Irrigation' 'Drought' 'Drougth - grassland' 'Irrigation - grassland'
#  'freeze-thaw' 'Watering experiment - desert' 'Drougth experiment- desert'
#  'Warming experiment' 'Watering experiment' 'Drougth experiment'
#  'Wetting effect' 'CO2 enrichment' 'elevated CO2'
#  'CO2 enrichment  -Ecosystem type - Forest'
#  'CO2 enrichment - Ecosystem type - Grassland'
#  'CO2 enrichment - Ecosystem type - Desert'
#  'CO2 enrichment - Ecosystem type - Wetland'
#  'CO2 enrichment - Ecosystem type - Cropland' 'Exp warming - Shrubland'
#  'Exp warming' 'Exp warming - forest land' 'Exp warming - grassland'
#  'Exp warming - Tundra' 'Exp warming - Wetland' 'Warming'
#  'Warming - Grassland' 'Warming - Forest' 'Forest/ nitrogen addition'
#  'Experimental warming -Forest' 'Experimental warming - Grassland'
#  'Experimental warming' 'increasing snow pack depth' 'snow manipulation'
#  'removal snow pack depth' 'increasing snow pack depth - Forest'
#  'increasing snow pack depth - grassland'
#  'Rainfall reduction - Ecosystem type - Shrub' 'Rainfall reduction'
#  'Rainfall reduction -Ecosystem type - Forest'
#  'Rainfall reduction - Ecosystem type - Grassland'
#  'Warming -Ecosystem type - Shrubland'
#  'Warming - biomes : Ecosystem type - Tundra'
#  'Warming - N addition - ecosystem type - Cropland'
#  'Warming - Ecosystem type - Grassland' 'Warming -Ecosystem type - Forest'
#  'C02 elevation and N ferti' 'C02 elevation and only N ferti'
#  'C02 elevation and nutrient adition'
#  'C02 elevation and No nutrient addition'
#  'C02 elevation with pure N fertilization' 'C02 elevation and NPK ferti'
#  'C02 elevation' 'N ferti' 'Elevated CO2'
#  'previous land-use->Agrisilvicultural' 'previous land-use->agroforestry'
#  'before-after->agroforestry' 'Degraded fallow->agroforestry'
#  'unshaded system->agroforestry' 'cropland->woodland'
#  'underutilsed land->agroforestry' 'fallow land->woodlands'
#  'previous land-use->woodlots' 'Fallow->agroforestry'
#  'Unshaded->agroforestry' 'Underutilized->agroforestry' 'Under Canopy'
#  'type: tree' 'Planted fallow' 'Biomass transfer' 'Mulch' 'Alley cropping'
#  'Hedgerow' 'Intercrop' 'no till' 'cropland-> Agrisilviculture' 'Overall'
#  'Forest->agroforestry' 'PAsture->agroforestry'
#  'Pasture to Arid_Silvopasture ' 'cropland->agrosilvopasture'
#  'cropland->Multistrata systems' 'UNcultivated land->agroforestry'
#  'cropland-> Silvopasture' ' Agrisilviculture'
#  'uncultivated land->agroforestry' 'Overall to Arid_silvopasture '
#  'Overall to Arid_Agrisilviculture' 'Overall to Arid_Agrosilvopasture '
#  'PAsture->Agrisilvicultural'
#  'Cropland/forest land/grassland to Trop_Agrosilvopasture'
#  'Cropland/Forest/grassland/others lands to Trop_Agrisilviculture '
#  'grassland/other land to Trop_Silvopasture'
#  'Agriculture/forest  to multistrata systems'
#  'Grassland_other land to Trop_Agrisilvopasture  '
#  'Cropland to Silvopasture ' 'cropland->Silvoarable'
#  'Cropland/forest land to Agrisilviculture '
#  'Forest land/grassland to Silvopasture '
#  'Other land to Agrosilvopasture '
#  'cropland/grassland to Agrisilviculture '
#  'Cropland/grassland/other land to Agrisilviculture'
#  'cropland/forest land to Agrisilviculture '
#  'Forest land/grassland to Agrosilvopasture '
#  'cropland/forest land/grassland to Silvopasture'
#  'cropland/forest land/grassland/other lands to Agrisilviculture'
#  'Forest land/grassland to Silvopasture' 'Temperature increase'
#  'Precipitation increase' 'Precipitation reduction' 'NP fertilization'
#  'P fertilization' 'cropland->Alley cropping' 'cropland->Windbreaks'
#  'cropland->Homegardens' 'hedgerow/grass field margins' 'organic farming'
#  'Organic fertilization' 'Organic + Inorganic fertilization'
#  'Fertilization - Overall' 'Inorganic N fertilization'
#  'Inorganic NP fertilization' 'Inorganic NPK fertilization' 'N addition'
#  'Nitrogen addition' 'Nitrogen addition - Forest'
#  'bioenergy ash application' 'wildfire ash application' 'Fertilizer'
#  'Chemical fertilizer with straw application'
#  'Unbalance application chemical fertilizer'
#  'Balance application chemical fertilizer' 'Fertilizer: N addition'
#  'Fertilizer : NK addition' 'Fertilizer : NP addition'
#  'Fertilizer : NPK addition' 'Fertilizer : P addition'
#  'Fertilizer : PK addition' 'Chemical fertilizer with manure application'
#  'long term application of K ferti' 'long term application of N ferti'
#  'long term application of NK ferti' 'long term application of NP ferti'
#  'long term application of NPK ferti'
#  'long term application of N/P/K ferti' 'long term application of P ferti'
#  'long term application of PK ferti'
#  'N addition - Ecosystem type - Grassland'
#  'N addition Ecosystem type - Desert' 'fertilizer Organic'
#  'Organic N (Farm yard manure or compost)' 'Organic (manure or compost)'
#  'Rotation : annual : all crops' 'Continous rice' 'Fertilization: N only'
#  'Fertilization: NPK' 'Mineral N (N or NPK)' 'Straw retained'
#  'Straw removed' 'Fertilizer mineral'
#  'Fertilization (mineral N) + straw retained'
#  'Fertilization  (mineral N)+ straw removed' 'N addition to ecosystems'
#  'N addition to ecosystems - Grassland'
#  'N addition to ecosystems - Forest' 'ALL' 'NP addition' 'NPK addition'
#  'N addition - Ecosystem - Cropland' 'N addition - Ecosystem - forest'
#  'N addition - Ecosystem - Desert/Shrub' 'N addition Ecosystem - Tundra'
#  'earthworms abundance' 'N addition - Ecosystem type - Non agriculture'
#  'N addition - Ecosystem type - Agriculture'
#  'N addition Ecosystem type - Forest'
#  'N addition - Ecosystem type - Others'
#  'N addition - ecosystem type - Cropland' 'K ferti' 'NPK ferti' 'P ferti'
#  'Addition of P' 'Se fertilization' 'Organic fertilizer (final stage)'
#  'Combined chemical + organic fertilizer (final stage)'
#  'No fertilizer (final stage)' 'Chemical fertilizer (final stage)'
#  'Straw return (final stage)' 'Manure only'
#  'Manure + chemical fertilizers (CFM)'
#  'Straw residue retention + chemical fertilizers'
#  'Balanced chemical fertilization of N, P, and K'
#  'Unbalanced chemical fertilization of N, or P, or K'
#  'Straw residue retention only' 'NPK' 'NPK+ Manure' 'Manure'
#  'ferti: Manure' 'Ferti: Manure' 'ferti: Manure +N' 'ferti: Manure +  NP'
#  'ferti: Manure +  NPK' 'ferti: N' 'ferti: NK' 'ferti: NP' 'ferti: NPK'
#  'ferti : NPK' 'ferti: NPSK' 'ferti: NPKS' 'Ferti : NPKS' 'ferti: NPS'
#  'ferti: NS' 'ferti: S' 'Ferti: S'
#  'Substitution of inorganic fertilizer N with organic amendments'
#  'Substitution of inorganic fertilizer N with organic amendments - low'
#  'Inorganic N addition' 'Split inorganic N addition'
#  'Deep placement of inorganic N addition'
#  'Enhanced-efficiency N fertilizers' 'Organic N'
#  'Integrated (organic + synthetic N)'
#  ' Integrated (organic + synthetic N)' 'N fertilization : synthethic N'
#  'fertilizer, liming and grazing' 'Liming' 'P addition' 'Grazing'
#  'nitrogen addition' 'intensity: heavy' 'intensity: light'
#  'intensity: moderate' 'Fire'
#  'Alternate wetting and drying + mid-season drainage'
#  'young ex arable->abandonment : old ex-arable' 'Cropland->abandonment'
#  'pasture/grassland->abandonment' 'non forested->forested'
#  'non forested (Barren land)->forested' 'cropland->forested'
#  'all land use->forested' 'pasture/grassland->forested'
#  'wildland->forested' 'industrial->forested' 'no forested->forested'
#  'heathland->forested' 'barren land->forested'
#  'grassland/other land->forested' 'cropland/pasture/bare area->forested'
#  'pasture/grassland->cropland' 'High C input with amendments'
#  'High C input' 'Low C input' 'Conventionnal tillage'
#  'native->cultivation' 'native->set aside' 'other land use->all'
#  'other land use->dowstream' 'other land use->upstream'
#  'other land use->midstream' 'cropland->other land types'
#  'cropland->other' 'forested->Cropland' 'forested->grassland'
#  'forested->shrubland' 'forested->other land types'
#  'pasture/grassland->other land types' 'shrubland->grassland'
#  'forested->forested' 'other land use->' 'cropland-> forested'
#  'cropland-> pasture/grassland' 'cropland->grassland'
#  'cropland-> shrubland' 'vegetation->forested' 'Cropland'
#  'Perennial cropland' 'Grassland' 'Plantation' 'plantation'
#  'Secondaryforest' 'Secondary forest' 'forested->Secondary forest'
#  'Harvesting intensity - Stem-only harvesting'
#  'Harvesting intensity - Prescribed burning following harvest or salvage logging following wildfire'
#  'Harvesting intensity - Whole-tree harvesting'
#  'Harvesting intensity - Partial harvesting'
#  'pasture/grassland or pasture->forested' 'baren land->forested'
#  'primary or forested->' 'cropland->grassland ' 'forested->cropland'
#  'forested->cropland ' 'N fertilizer added' 'forested->no-tillage'
#  'mangrove->tree removal' 'mangrove->rice fields'
#  'mangrove->other categories' 'mangrove->all'
#  'mangrove->pasture/grassland' 'mangrove->pasture' 'mangrove->aquaculture'
#  'forested->pasture' 'cropland->pasture' 'overall->overall'
#  'pasture/grassland->' 'cropland- > forest fallow'
#  'forested->shifting cultivation' 'savanna->cropland' 'savanna->forested'
#  'savanna->pasture' 'cropland-> grassland' 'cropland -> natural fallow'
#  'foresteded->grassland' 'cropland->perennial crops'
#  'cropland-> perennial grasses' 'cropland-> perenial grasses'
#  'cropland->perenial grasses' 'cropland -> short rotation coppice'
#  'cropland-> rotation coppice' 'forest land -> short rotation coppice'
#  'forested-> perennial grasses' 'forested-> 1st Gen energy crops'
#  'pasture/grassland-> perenial grasses'
#  'pasture/grassland-> rotation coppice' 'perennial grasses'
#  'pasture/grassland->1st Gen energy crops' 'cropland->corn'
#  'cropland->ecrop' 'forested-> energy crop : short rotation coppice'
#  'pasture/grassland->energy crop : short rotation coppice'
#  'pasture/grassland-> energy crop : perennial grasses'
#  'forest land-> energy crop : short rotation coppice'
#  'pasture/grassland-> energy crop : short rotation coppice'
#  'pasture/grassland->  energy crop : perennial grasses' 'Cutting: ALL'
#  'Cutting: Heavy' 'Cutting: moderate' 'Cuttng: ALL' 'Cutting: light'
#  'forested-> forested' 'Natural forest -> plantation' 'Cropland-> forest'
#  'Cropland->grassland' 'shrub land->shrub removal'
#  'cropland->all vegetation restauration' 'cropland->shrubland'
#  'all->all vegetation restauration'
#  'non-crop land->all vegetation restauration' 'pasture->grassland'
#  'wetland->forested' 'wetland cultivation' 'forested->wetland'
#  'pasture/grassland->wetland' 'Pasture/grasland->wetland'
#  'wetland->wetland' 'woody plants retained->woody plants removal'
#  'biological intervention' 'exclosure' 'stone bunds'
#  'stone bunds and biological intervention' 'terracing'
#  'conservation agriculture' 'Improved management practice - All'
#  'Improved management practice - Organic manure'
#  'Improved management practice - Mineral fertilizer + Organic manure'
#  'Improved management practice - Straw return'
#  'Improved management practice - Reduced or no tillage'
#  'Organic matter addition' 'Organic agriculture' 'CO2 enrichissment '
#  'Exp. Drought' 'Fertilizer - Grassland' 'Fertilizer -Forest'
#  'Biomass burning' 'Crop residues incorporation' 'residue retention'
#  'Rotation : with or without'
#  'Intermediate tillage (e.g. chisel, disk, harrow and mulch plough)'
#  'manure application' 'chemical fertilization application'
#  'no-till with residue removal' 'residue retained'
#  'no-till with residue retained' 'Litter removal - Grassland'
#  'Litter addition - grassland' 'Litter addition - Grassland'
#  'Litter removal' 'Litter addition' 'litter Exclusion' 'Litter exclusion'
#  'No till + residue retention' 'No till + residue removed'
#  'no-tillage (previous land-use)->integrated crop-livestock'
#  'savannah/forested->full-tillage' 'no-till' 'savannah->no-tillage'
#  'full tillage->no-tillage' 'details' 'organic C addition'
#  'Recomanded practices' 'Animal manure application'
#  'Crop residue recycling' 'Reduced no tillage' 'Corn stover removal'
#  'Three crops in rotation' 'Two crops in rotation'
#  'crop frequency : double (2 crops per year)' 'crop diversity:two types'
#  'intermediate intensity tillage' 'zero tillage' 'no tillage'
#  'rotation : annual : all crops ;' 'corn-soybean ' 'corn rotation'
#  'rotations with grass, hay, or pasture ' 'soybean rotations'
#  'continous wheat' 'wheat rotations'
#  'changing from monoculture to continuous rotation cropping, changing  crop_fallow to continuous monoculture or rotation cropping,orincreasingthenumberofcropsinarotation system'
#  'rotation soybean' 'Continous corn' 'rotation siybean'
#  'corn soybean rotations' 'rotation corn no soybean' 'all soybean'
#  'all corn systems' 'Rotation wheat' 'rotation corn' 'monocultures'
#  'all rotation no wheat fallow' 'continous soybean'
#  'all systems no wheat fallow' 'rotation no wheat fallow'
#  'Continous wheat' 'all wheat systems' 'Wheat fallow' 'Animal manure'
#  'no tillage + cover crop' 'minimum tillage' 'high biomass rice cultivar'
#  'polluted soils (Nemero Synthesis Index)'
#  'polluted soils (Nemero Synthesis Index) - Agricultural land'
#  'polluted soils (Nemero Synthesis Index) - Natural land' 'Heavy metals'
#  'biochar application' 'biochar application - Forest'
#  'biochar application - Grassland' 'Shrub-encroached grassland'
#  'Acid addition' 'Shrub or herbaceous microsite' 'Shrub microsite'
#  'Herbaceous microsite' 'biotic disturbance' 'Opportunistic observation'
#  'Manipulative experimentation' 'Insect' 'pathogen'
#  'Defoliation in Forest' 'Defoliation in all data' 'Mortality' 'Moth'
#  'Aphid' 'Beetle' 'XXXX' 'Main' 'Biotic disturbance' 'Plant invason'
#  'PLant invason' 'CO2 + Warming' 'Precipitation increased'
#  'Slightly degraded alpine meadow' 'Moderately degraded alpine meadow'
#  'Severely degraded alpine meadow' 'Very severely degraded alpine meadow'
#  'Conservation tillage + Cover crops' 'Conservation tillage'
#  'Intensive forest harvest (tree stems + logging residues)'
#  'Conventional forest harvest (tree stems, clear-cutting)'
#  'Conventional forest harvest (tree stems, clear-cutting or thinning)'
#  'Conventional forest harvest (tree stems, thinning)'
#  'barren land or cropland->forested' 'sucession->forested'
#  'sucession->forested (Conversion cropland to grassland)'
#  'sawlog harvesting' 'Harvesting (all)' 'Whole tree harvesting'
#  'Biochar addition' 'C02 + Drought' 'CO2 + rainfall' 'CO2 + N'
#  'CO2 + N - grassland' 'CO2 + Warming - Grassland' 'CO2+ Warming' 'CO2'
#  'CO2 - Grassland' 'N + drougth' 'N+ rainfall' 'N+ rainfall - grassland'
#  'N + rainfall' 'Warming + drought' 'warming + rainfall'
#  'Warming + Rainfall' 'Warming + drought - grassland' 'Increase rainfall'
#  'Warming + N' 'Warming +N' 'Warming +N - grassland' 'Drought - Grassland'
#  'Increase rainfall - grassland' 'Rainfall' 'N addition - Grassland'
#  'N+P addition' 'N+P addition - Grassland' 'N+ P addition'
#  'P addition - Grassland' 'N addition- desert' 'Biochar - Farmland'
#  'Plant invasion' 'Plant invasion - Forest' 'Plant invasion - grassland'
#  'mineral fertilization' 'Overgrazing' 'stem only havesting'
#  'Forest Thining'
#  'N-(n-butyl) thiophosphoric triamide (NBPT) treated urea'
#  'pasture/grassland->restauration'
#  'Reduced synthetic N application - Urea (< 200 kg N ha-1)'
#  'N inhibitor or slow releasing N fertilizer '
#  'Straw, Straw + NPK application' 'Manure, Manure + NPK application'
#  'Green manure, NPK + manure' 'Livestock manure, NPK + manure'
#  'Biogas residue, NPK + biogas residue' 'conservation tillage'
#  'Integrated farming (Rice-duck, rice-fish farming)'
#  'Reduced synthetic N application (113 kg N ha-1)'
#  'Reduced synthetic N application (127 kg N ha-1)'
#  'Reduced synthetic N application (107 kg N ha-1)'
#  'Reduced synthetic N application (158 kg N ha-1)'
#  'N inhibitor or slow releasing N fertilizer - Coated fertilizer'
#  'N inhibitor or slow releasing N fertilizer - Urea formaldehyde'
#  'N inhibitor or slow releasing N fertilizer - N inhibitor'
#  'Ungrazed grassland' 'Reduced grazing intensity'
#  'Grazing exclusion (Ungrazed grassland)'
#  'Restoration of degraded grassland'
#  'Earthworms addition or non-reduced earthworm abundance'
#  'monoculture plots->agroforestry' 'pasture/grassland->cropland ']
# Total unique in treatment_authors: 708
# Unique values in management: ['PyC:SOC Ratio <2' 'Overall PyC:SOC Ratio' 'PyC:SOC Ratio >2'
#  'PyC:SOC Ratio <2 Addition rate :' 'PyC:SOC Ratio >2 no fertilization'
#  'PyC:SOC Ratio <2 NPK fertilization' 'PyC:SOC Ratio >2 NPK fertilization'
#  'PyC:SOC Ratio > 2' 'PyC:SOC Ratio < 2' '-' 'PyC:SOC Ratio >2 '
#  'Fire : prescribed fire' 'Fire : wildfire' 'afforestation'
#  'Addition rate :0 kg N ha-1 yr-1' 'Biochar only'
#  'Biochar feedstock: papermill residues'
#  'Biochar feedstock: Ligneous materials' 'Addition rate : 10-20tha-1yr-1'
#  'Biochar T°: 550-700°C' 'Biochar T°: 400-500°C'
#  'Addition rate : 5-10tha-1yr-1' 'Addition rate :<100 kg N ha-1 yr-1'
#  'Addition rate : <6tha-1yr-1' 'Biochar + inorganic Fertilizer'
#  'Addition rate :>200 kg N ha-1 yr-1' 'Biochar feedstock: cereal residues'
#  'Biochar T°: <400°C' 'Addition rate :100-200 kg N ha-1 yr-1'
#  'Biochar T°: >700°C' 'Biochar T°: 400-550°C'
#  'Biochar + organic amendments' 'Addition rate : <5tha-1yr-1'
#  'Biochar feedstock: animal and human wastes' 'Biochar pH >9'
#  'Biochar pH <9' 'Addition rate : <20 t ha yt-1' 'Addition rate : all'
#  'Addition rate : >20 t ha yt-1' 'Agroforestry' 'ALL = manag'
#  'Agroforestry : Agrisilvicultural' 'Agroforestry : silvopastoral'
#  ' Agroforestry : Agrosilvopasture' 'early seral statuses'
#  'Fire: no wildfire after treament' 'Fire : wildfire after treatment'
#  'mid/late seral statuses' 'Addition rate :150-200 kg N ha-1'
#  'Addition rate :Overall' 'Addition rate :<150 kg N ha-1'
#  'Addition rate :>=200 kg N ha-1' 'Addition rate : >=200 kg N ha-1'
#  'Addition rate :overall' nan 'Broadcast burn + replanting'
#  'Natural regeneration' 'Forest : plantation' 'substitution: 100%'
#  'substitution: 100% -High rates' 'substitution: 100% -low rates'
#  'substitution:  100% ' 'substitution: 100% - raw manure'
#  'substitution: 100% - manure composted'
#  'substitution: 100% -moderate rates' 'substitution:  100%'
#  'substitution: 100% ' 'substitution: <100%'
#  'substitution: <100% -High rates' 'substitution: ALL -High rates'
#  'substitution:  ALL' 'substitution: ALL' 'substitution:  ALL -raw manure'
#  'substitution: ALL -moderate rates' 'substitution: 40-60%'
#  'substitution: <100% -low rates' 'substitution: ALL -manure composted'
#  'substitution: ALL ' 'substitution:  ALL -low rates'
#  'substitution:  ALL ' 'substitution: <100% -moderate rates'
#  'substitution: 60-100%' 'substitution: <100% - manure composted'
#  'substitution: <100% ' 'substitution: <60%' 'substitution:  < 100%'
#  'substitution:  <100% ' 'substitution: < 100%' 'residues : retention'
# ...
#  'Soil sand content' 'Soil clay content' 'animal' 'earthworm abundance'
#  'Soil respiration' 'Economic benefit' 'lignin' 'eveness']
# Total unique in details_outcome: 103
# Unique values in N_paired_data: ['179' '268' '89' '23' '29' '61' '85' '3' '65' '22' '25' '6' '83' '35'
#  '58' '46' '109' '8' '12' '97' '14' '32' '54' '24' '53' '5' '19' '140'
#  '10' '37' '64' '110' '28' '21' '80' '48' '62' '44' '75' '45' '31' '82'
#  '26' '47' '39' '34' '17' '27' '52' '49' '79' '30' '87' '123' '36' '51'
#  '16' '72' '117' '2' '76' '20' '7' '144' '38' '42' '69' '9' '145' '139'
#  '240' '228' '74' '77' '95' '67' '73' '11' '120' '167' '281' '1249' '699'
#  '57' '452' '181' '251' '331' '1462' '156' '1195' '259' '106' '262' '166'
#  '174' '288' '183' '317' '43' '96' nan '60' '146' '13' '50' '133' '63'
#  '385' '151' '70' '299' '59' '101' '225' '18' '173' '125' '160' '41' '112'
#  '1' '4' '15' '100' '93' '90' '55' '129' '107' '78' '131' '40' '81' '159'
#  '232' '194' '177' '127' '94' '91' '56' '99' '170' '33' '66' '92' '230'
#  '180' '116' '276' '341' '122' '512' '86' '256' '380' '267' '189' '198'
#  '389' '108' '290' '193' '237' '102' '176' '235' '118' '134' '152' '291'
#  '310' '239' '215' '143' '304' '172' '381' '294' '236' '335' '188' '214'
#  '162' '168' '119' '128' '105' '113' '226' '264' '111' '132' '206' '339'
#  '136' '114' '130' '445' '342' '158' '191' '178' '221' '103' '471' '104'
#  '147' '192' '349' '289' '453' '161' '88' '98' '265' '135' '138' '68'
#  '182' '121' '370' '223' '255' '141' '84' '308' '408' '436' '154' '155'
#  '418' '238' '137' '71' '347' '233' '-' '244' '271' '142' '175' '224'
#  '150' '169' '217' '367' '343' '216' '126' '212' '469' '368' '298' '361'
#  '665' '515' '242' '437' '2092' '307' '297' '245' '303' '246' '165' '115'
#  '383' '218' '542' '422' '636' '278' '260' '293' '234' '171' '157' '149'
#  '148' '196' '?' '153' '163' '201' '185' '124' '864' '312' '326' '229'
#  '378' '505' '555' '321' '1152' '197' '248' '545' '258' '220' '318' '1213'
#  '554' '327' '305' '486' '1010' '388' '284' '211' '352' '824' '279' '357'
#  '356' '375' '346' '487' '329' '203' '328' '164' '209' '241' '202' '286'
#  '222' '227' '778' '441' '186' '532' '252' '319' '274' '485' '243' '480'
#  '261' '200' 'Na' '427' '187' '207' '433' '635' '213' '295' '470' '451'
#  '429' '415' '320' '285' '416' '372' '391' '693' '652' '205' '1033' '1343'
#  '399' '1243' '273' '600' '827' '620' '324' '395' '1185' '595' '272' '323'
#  '306' '340' '1111' '2494' '396' '2013' '190' '1077' '2090' '719' '1276'
#  '2144' '1598' '1399' '681' '511' '688' '409' '506' '799' '528' '536'
#  '2393' '208' '682' '788' '524' '1282' '413' '1437' '1060' '334' '459'
#  '1466' '1050' '1473' '1190' '956' '301' '1383' '2456' '500' '745' '642'
#  '407' '1489' '522' '1924' '1606' '1319' '449' '421' '484' '806' '710'
#  '726' '679' '615' '263' '219' '344' '195' '296' '521' '423' '490' '184'
#  '462' '332' '1140' '814' '1490' '337' '282' '247' '411' '351' '325' '392'
#  '537' '280' '424' '12 primary studies' '10 primary studies'
#  '6 primary studies' '333' '733' '400' '717' '350' '902' '386' '802' '314'
#  '520' '316' '269' '210' '204' '249' '199' '460' '397' '257' '657' '402'
#  '384' '1306' '1295' '432' '1064' '1477' '1772' '426' '527' '428' '547'
#  '692' '725' '250' '358' '687' '816' '815' '871' '839' '880' '478' '594'
#  '770' '805' '464' '270' '322' '558' '482' '648' '365' '406' '508' '677'
#  '1187' '1712' '525' '1023' '398' '254' '468' '2180' '345' '746' '945'
#  '371' '287' '401' '821' '585' '354' '1274' '650']
# Total unique in N_paired_data: 536
# //////////////////Unique values for df_primary:
# Unique values in Primarystudies_Country: ['Denmark' 'Sweden' 'Iran' 'Cameroon' 'China' 'Costa Rica' 'USA' 'Ecuador'
#  'India' 'Germany' nan 'UK' 'Kenya' 'malawi' 'Burkina Faso' 'Senegal'
#  'Taiwan' 'Philippines' 'Australia' 'Japan' 'Indonesia' 'Brazil' 'France'
#  'Spain' 'Argentina' 'United Arab Emirates' 'Canada' 'Italy' 'Mali'
#  'Ghana' 'spain' 'Puerto Rico' 'Nepal' 'Tunisia' 'Zambia' 'Malawi'
#  'Mexico' 'Belgium' 'The Netherlands' 'Switzerland' 'Ireland' 'Thailand'
#  'Ethiopia' 'italy' 'china' 'Serbia' 'Peru' 'Zimbabwe' 'Global'
#  'Kenya, Indonesia' 'Estonia' 'Costa Rica, Canada' 'Colombia'
#  'South Africa' 'Norway' 'india' 'Nigeria' 'Botswana' 'Namibia' 'Turkey'
#  'Finland' 'Chile' 'New Zealand' 'Uruguay' 'Malaysia' 'Iceland' 'Poland'
#  'Congo' 'Uzbekistan' 'Russia' 'Bolivia' 'chile' '\ufeffguinea bissau'
#  'Panama' 'switzerland' 'Czech Republic' 'South Korea' 'Benin' 'Honduras'
#  'Togo' 'Sudan' 'Vietnam' 'argentina' 'The netherlands' 'Portugal'
#  'indonesia' 'Papua New Guinea' 'Austria' 'Tanzania' 'Venezuela' 'Hungary'
#  'Laos' 'Niger' 'Ivory Coast' 'Madagascar' 'Greenland' 'Guatemala'
#  'Nicaragua' 'East Timor' 'KEnya' 'Usa' 'Myanmar' 'Liberia' 'NIgeria'
#  'Slovakia' 'Uganda' 'global' 'ireland' 'Dominican Republic' 'Gabon'
#  'Belize' 'Luxembourg' 'Southern Africa' 'Jordan' 'Egypt' 'Pakistan'
#  'Greece' 'germany' 'Czech republic' 'Mongolia' 'Bangladesh' 'Israel'
#  'Sri Lanka' 'Lithuania' 'the netherlands' 'Antarctica' 'sweden' 'Rwanda'
#  'Gambia' 'Malawi, Tanzania' 'Bulgaria' 'Morocco' 'burkina Faso' 'japan'
#  'South Sudan' 'uk' 'Cambodia' 'austria' 'Croatia' 'Cuba' 'Swizerland'
#  'Syria' 'iran' 'the Netherlands' 'russia' 'Mozambique' 'Paraguay'
#  'Bosnia and Herzegovina' 'Slovenia' '\ufeffswitzerland\t'
#  '\ufeffnetherlands' 'malawi, mozambique' 'Algeria' 'Oman' 'French Guiana'
#  '\ufeffAzerbaijan' 'hungary' 'South africa' 'Latvia' 'Kyrgyzstan'
#  'Guinea-Bissau' 'turkey' 'Romania' 'netherlands' 'Papua new guinea'
#  'New zealand' 'Belarus' 'Peru, Italy' '\ufeffrepublic of congo' 'Moldova'
#  'australia' 'All continents' 'PAPUA NEW GUINEA'
#  '\ufeffrepublic of serbia' 'Kazakhstan' 'World' 'Papua New guinea'
#  'belize' 'puerto rico' 'canada' 'Saudi Arabia' 'worldwide' 'UK, Spain'
#  '\ufeffliechtenstein' 'Argentine' 'Swaziland' 'Solomon Islands' 'norway'
#  'Guinea' 'Guam' 'Puerto rico' 'Ukraine' 'usa' 'Somalia' 'venezuela'
#  'Suriname' 'vietnam']
# Total unique in Primarystudies_Country: 197
# Unique values in intervention: ['LUC' 'LUC, Manag' 'Manag' nan 'Global_Changes, Manag' 'Global_Changes'
#  'Others' 'MAnag' 'Global_changes, LUC' 'global_Changes, Manag, LUC'
#  'manag' 'Na' 'na']
# Total unique in intervention: 13
# Unique values in Outcome: ['Soil_carbon ' ' Soil_chemistry, ' 'Soil_carbon, Soil_chemistry, '
#  ' Plant_production, Soil_carbon ' ' GHG, Plant_production, Soil_carbon '
#  ' GHG, Soil_carbon ' 'Soil_carbon, Soil_physics '
#  ' Plant_production, Soil_biology, Soil_carbon '
#  ' Plant_production, Soil_carbon, Soil_chemistry, Soil_physics '
#  'Assoc_biodiv, GHG, Plant_production, Soil_carbon '
#  ' Plant_production, Soil_carbon, Soil_chemistry, '
#  'Economy,  Soil_carbon '
#  ' Plant_production, Soil_carbon, Water_quality, '
#  ' Soil_biology, Soil_carbon, Soil_physics '
#  ' Soil_biology, Soil_carbon, Soil_chemistry, '
#  ' Soil_biology, Soil_carbon ' 'Soil_carbon, Water_quality, '
#  ' Soil_biology, ' ' Plant_production, '
#  ' Plant_production, Soil_biology, ' 'Soil_physics '
#  'Soil_carbon, Water_use' ' Plant_production, Soil_physics '
#  'Assoc_biodiv, Soil_chemistry, Soil_physics ' 'Pest_and_diseases '
#  ' GHG, ' ' Plant_production, Soil_carbon, Soil_physics '
#  ' GHG, Soil_chemistry, ' 'Soil_carbon, Soil_physics Water_use' 'Economy'
#  ' Plant_production, Soil_chemistry, ' ' Soil_biology, Soil_chemistry, '
#  ' litter, Soil_chemistry' ', ' 'Soil_physics Water_use' 'Water_use'
#  ' GHG, Water_use' 'Assoc_biodiv, Soil_carbon, Soil_chemistry, Water_use'
#  'Assoc_biodiv, ' 'Assoc_biodiv, Plant_production, '
#  ' Plant_production, Soil_biology, Soil_physics '
#  ' GHG, Plant_production, Soil_biology, Soil_chemistry, '
#  ' Plant_production, Soil_biology, Soil_chemistry, '
#  ' GHG, Plant_production, ' 'Assoc_biodiv, GHG, Plant_production, '
#  ' GHG, Plant_production, Soil_biology, '
#  'Soil_carbon, Soil_chemistry, Soil_physics '
#  ' GHG, Plant_production, Soil_biology, Soil_physics '
#  'Pest_and_diseases, Plant_production, '
#  ' GHG, Plant_production, Soil_chemistry, '
#  ' GHG, Input_use_efficiency, Plant_production, '
#  'Assoc_biodiv, Soil_biology, Soil_chemistry, ' ' litter, '
#  ' Plant_production, Water_use' ' Soil_chemistry, Soil_physics '
#  ' GHG, Water_quality, ' ' Water_quality, '
#  ' Plant_production, Water_quality, '
#  'Assoc_biodiv, Soil_carbon, Soil_chemistry, '
#  ' GHG, Plant_production, Water_use'
#  ' Plant_production, Soil_chemistry, Water_use'
#  ' Plant_production, Soil_biology, Soil_carbon, Soil_chemistry, '
#  'Soil_carbon, Soil_physics, Water_quality, ' ' GHG, Soil_biology, '
#  ' GHG, Soil_carbon, Soil_chemistry, ' 'Pest_and_diseases Soil_physics '
#  ' Plant_production, Soil_biology, Soil_chemistry, water_use'
#  ' Soil_chemistry, Soil_physics, Water_quality, '
#  ' Soil_biology Water_quality, '
#  'Pest_and_diseases, Plant_production, Soil_chemistry, '
#  ' Water_quality, Water_use' 'Assoc_biodiv, Soil_chemistry, '
#  'Assoc_biodiv, Soil_carbon '
#  'Soil_carbon, Soil_chemistry, Soil_physics Water_use'
#  'Soil_carbon, Water_quality, Water_use' ' litter, Soil_carbon '
#  ' Soil_chemistry, Water_quality, ' ' GHG, Soil_biology, Soil_carbon '
#  'Input_use_efficiency' 'Pest_and_diseases Soil_carbon '
#  ' GHG, Soil_biology, Soil_chemistry, ' ' Soil_biology, Soil_physics '
#  ' Plant_production, Soil_biology, Soil_physics, Water_quality, '
#  ' GHG, Pest_and_diseases '
#  ' Plant_production, Soil_biology, Soil_chemistry, Water_quality, '
#  ' Plant_production, Soil_chemistry, Soil_physics '
#  ' GHG, Soil_carbon, Water_quality, '
#  ' Plant_production, Soil_biology Water_quality, ' 'pollution '
#  'Assoc_biodiv, Soil_biology, '
#  ' Soil_biology, Soil_chemistry, Water_quality, '
#  'Assoc_biodiv, Soil_biology, Soil_carbon '
#  'Pest_and_diseases, Soil_biology, '
#  ' Soil_biology, Soil_chemistry, Water_use'
#  'Assoc_biodiv, Pest_and_diseases ' 'pollution, Soil_chemistry, '
#  'Input_use_efficiency, Soil_chemistry, ' 'Soil_physics , Water_quality, '
#  ' Plant_production, pollution, Soil_biology, '
#  ' Plant_production, Soil_physics Water_use'
#  ' Plant_production, pollution, Soil_biology, Soil_chemistry, '
#  'Soil_carbon, Soil_chemistry, Soil_physics, Water_quality, '
#  'Soil_carbon, Soil_chemistry, Water_quality, '
#  ' Soil_biology, Soil_chemistry, Soil_physics '
#  ' Soil_chemistry, Water_use' ' GHG, Soil_chemistry, Water_use'
#  ' Plant_production, Soil_carbon, Soil_chemistry, Soil_physics, Water_quality, '
#  ' Soil_biology, Water_use' 'Assoc_biodiv, GHG, '
#  ' GHG, Plant_production, Soil_physics '
#  ' Plant_production, Soil_chemistry, Water_quality, '
#  ' GHG, Plant_production, water_use'
#  'Pest_and_diseases, Plant_production, Soil_biology, Soil_chemistry, '
#  ' Plant_production, Soil_carbon, Water_use'
#  'Pest_and_diseases, Plant_production, Soil_biology, '
#  ' GHG, Plant_production, Soil_biology, water_use'
#  'Input_use_efficiency, Plant_production, '
#  ' Plant_production, Soil_carbon, Soil_physics, Water_quality, '
#  'Assoc_biodiv, Soil_physics ' ' Soil_chemistry, Water_quality, Water_use'
#  ' Plant_production, Soil_biology, Soil_carbon, Soil_physics '
#  'Assoc_biodiv, Pest_and_diseases, Soil_biology, '
#  ' Plant_production, Soil_carbon, Soil_chemistry, Water_quality, '
#  ' Soil_biology, Soil_carbon, Soil_chemistry, Soil_physics Water_use'
#  ' GHG, Soil_physics ' 'Economy, Soil_carbon, Soil_chemistry'
#  'Economy, GHG'
#  'Input_use_efficiency, Plant_production, Soil_biology, Soil_chemistry, '
#  'Economy, Soil_physics ' 'Economy, Pest_and_diseases '
#  'Economy, Plant_production' ' GHG, Plant_production, Water_quality, '
#  'Assoc_biodiv, Plant_production, Soil_biology, '
#  ' Plant_production, pollution, Soil_chemistry, '
#  'Soil_physics , Water_quality, Water_use'
#  ' GHG, Plant_production, pollution, Soil_chemistry, '
#  ' GHG, Plant_production, Soil_carbon, Soil_chemistry, '
#  ' GHG, Soil_biology, Water_use' ' GHG, Input_use_efficiency '
#  'Soil_carbon, Soil_chemistry, Water_use'
#  'Input_use_efficiency, Soil_carbon '
#  ' GHG, Input_use_efficiency Pest_and_diseases '
#  'Economy, Pest_and_diseases, Plant_production, Soil_carbon '
#  'Input_use_efficiency, Water_quality, '
#  'pollution, Soil_chemistry, Water_use'
#  ' Plant_production, pollution, Soil_biology Water_quality, '
#  'Assoc_biodiv, Plant_production, Soil_physics '
#  ' GHG, Input_use_efficiency, Plant_production, Soil_biology, '
#  'Input_use_efficiency, Plant_production, Soil_biology, '
#  ' Plant_production, Water_quality, Water_use'
#  ' GHG, Plant_production, Soil_chemistry, Water_quality, '
#  ' GHG, Plant_production, Soil_carbon, Soil_physics '
#  ' GHG, Input_use_efficiency, Soil_chemistry, '
#  'Input_use_efficiency, Plant_production, Soil_physics '
#  ' GHG, Plant_production, pollution, Soil_biology, Soil_chemistry, '
#  'Pest_and_diseases, Soil_chemistry, '
#  'Assoc_biodiv, Pest_and_diseases, Plant_production, Soil_chemistry, '
#  'Economy, Plant_production, Soil_chemistry'
#  ' Plant_production, Soil_biology, Soil_chemistry, Water_use'
#  'Assoc_biodiv, GHG, Plant_production, Soil_chemistry, '
#  'Economy, GHG, Plant_production, Soil_physics '
#  'Input_use_efficiency, Plant_production, Soil_chemistry, '
#  'pollution, Soil_biology, ' ' GHG, Pest_and_diseases, Soil_biology, '
#  ' GHG, Soil_biology Water_quality, '
#  'Assoc_biodiv, GHG, Plant_production, Soil_biology, '
#  'pollution, Soil_biology, Soil_chemistry, Soil_physics '
#  'Pest_and_diseases, Water_quality, '
#  ' Soil_biology, Soil_carbon, Water_quality, '
#  'pollution, Soil_biology, Soil_chemistry, '
#  'Assoc_biodiv, pollution, Soil_biology, '
#  'Input_use_efficiency, Soil_carbon, Soil_physics '
#  ' GHG, Plant_production, Soil_chemistry, Soil_physics '
#  ' Soil_biology, Soil_carbon, Water_use'
#  ' Plant_production, Soil_biology, Soil_carbon, Water_use'
#  'Economy, Plant_production, Soil_physics'
#  ' GHG, Soil_biology, Soil_physics '
#  'Pest_and_diseases, Plant_production, Soil_chemistry, Soil_physics '
#  ' Plant_production, Soil_physics, Water_quality, '
#  ' Soil_biology, Soil_carbon, Soil_chemistry, Soil_physics '
#  'Input_use_efficiency, Soil_biology, '
#  'Pest_and_diseases, Soil_biology, Soil_physics '
#  ' GHG, Soil_biology, Soil_carbon, Soil_chemistry, '
#  'Pest_and_diseases, Plant_production, Soil_physics '
#  'Pest_and_diseases Water_use' 'Economy, GHG, Plant_production, '
#  ' Plant_production, Soil_biology, water_use'
#  'Assoc_biodiv, Soil_biology Water_quality, '
#  'Assoc_biodiv, GHG Water_quality, '
#  'Economy, Plant_production, Soil_carbon ' 'Assoc_biodiv Water_quality, '
#  ' GHG, Plant_production, Soil_biology, Soil_carbon '
#  'pollution, Soil_chemistry, Water_quality, '
#  ' GHG, Pest_and_diseases, Soil_chemistry, '
#  ' GHG, Soil_chemistry, Water_quality, '
#  'Soil_carbon, Soil_chemistry, water_use'
#  'Input_use_efficiency, Soil_carbon, Soil_chemistry'
#  'Pest_and_diseases, Plant_production, Soil_biology, Soil_physics '
#  'Assoc_biodiv, Economy, Pest_and_diseases '
#  'Input_use_efficiency, Plant_production, Water_use' 'soil biology'
#  'Input_use_efficiency, Soil_physics '
#  ' GHG, Soil_chemistry, Soil_physics ' 'pollution Soil_physics '
#  ' GHG, Soil_chemistry, Soil_physics, Water_quality, '
#  'Soil_carbon, Soil_physics water_use' ' GHG, Soil_carbon, Water_use'
#  'Assoc_biodiv, Plant_production, water_use' 'pollution, Water_quality, '
#  'Assoc_biodiv, litter, ' ' GHG, Pest_and_diseases, Water_quality, '
#  'Assoc_biodiv, Pest_and_diseases, Soil_chemistry, '
#  ' Plant_production, Soil_carbon, Soil_chemistry, Soil_physics Water_use'
#  ' Soil_biology, Soil_chemistry, water_use'
#  'Pest_and_diseases, Plant_production, Water_quality, '
#  ' Soil_biology, Soil_carbon, Soil_chemistry, Water_use'
#  ' GHG, Soil_carbon, Soil_chemistry, Soil_physics '
#  'Pest_and_diseases, Soil_chemistry, Soil_physics '
#  ' GHG, Input_use_efficiency, Soil_chemistry, Water_quality, '
#  'Pest_and_diseases, Water_quality, Water_use'
#  ' GHG, Plant_production, Soil_biology, Soil_carbon, Soil_chemistry, '
#  'Input_use_efficiency, Plant_production, Water_quality, '
#  'Input_use_efficiency, Plant_production, Soil_biology, Soil_physics '
#  ' Plant_production, Soil_biology, Soil_carbon, Water_quality, '
#  'pollution, Soil_biology Water_quality, '
#  'Assoc_biodiv, Soil_biology, Soil_carbon, Soil_chemistry, ' nan]
# Total unique in Outcome: 227

# %%
#Country names

df_primary['Primarystudies_Country'] = df_primary['Primarystudies_Country'].apply(standardize_country_names)

print(df_primary['Primarystudies_Country'].unique())

#save processed primary studies after fixing country name
filename01 = 'df_Primarystudies_Country.csv'
full_path = os.path.join(paths['processed_data_path'], filename01)
df_primary.to_csv(full_path, index=False)

print(f'DataFrame successfully saved to: {full_path}')
print(f"Total entries in the processed dataset: {len(df_primary)}")
# Out:
# ['Denmark' 'Sweden' 'Iran, Islamic Republic of' 'Cameroon' 'China'
#  'Costa Rica' 'United States' 'Ecuador' 'India' 'Germany' 'None' 'Ukraine'
#  'Kenya' 'Malawi' 'Burkina Faso' 'Senegal' 'Taiwan, Province of China'
#  'Philippines' 'Australia' 'Japan' 'Indonesia' 'Brazil' 'France' 'Spain'
#  'Argentina' 'United Arab Emirates' 'Canada' 'Italy' 'Mali' 'Ghana'
#  'Puerto Rico' 'Nepal' 'Tunisia' 'Zambia' 'Mexico' 'Belgium' 'Netherlands'
#  'Switzerland' 'Ireland' 'Thailand' 'Ethiopia' 'Serbia' 'Peru' 'Zimbabwe'
#  'Global' 'Kenya, Indonesia' 'Estonia' 'Costa Rica, Canada' 'Colombia'
#  'South Africa' 'Norway' 'Nigeria' 'Botswana' 'Namibia' 'Finland' 'Chile'
#  'New Zealand' 'Uruguay' 'Malaysia' 'Iceland' 'Poland' 'Congo'
#  'Uzbekistan' 'Russian Federation' 'Bolivia, Plurinational State of'
#  'Guinea-Bissau' 'Panama' 'Czechia' 'Korea, Republic of' 'Benin'
#  'Honduras' 'Togo' 'Sudan' 'Viet Nam' 'Portugal' 'Papua New Guinea'
#  'Austria' 'Tanzania, United Republic of'
#  'Venezuela, Bolivarian Republic of' 'Hungary'
#  "Lao People's Democratic Republic" 'Niger' 'Madagascar' 'Greenland'
#  'Guatemala' 'Nicaragua' 'Timor-Leste' 'Myanmar' 'Liberia' 'Slovakia'
#  'Uganda' 'Dominican Republic' 'Gabon' 'Belize' 'Luxembourg' 'Jordan'
#  'Egypt' 'Pakistan' 'Greece' 'Mongolia' 'Bangladesh' 'Israel' 'Sri Lanka'
#  'Lithuania' 'Antarctica' 'Rwanda' 'Gambia'
#  'Malawi, Tanzania, United Republic of' 'Bulgaria' 'Morocco' 'South Sudan'
#  'Cambodia' 'Croatia' 'Cuba' 'Syrian Arab Republic' 'Mozambique'
#  'Paraguay' 'Bosnia and Herzegovina' 'Slovenia' 'Malawi, Mozambique'
#  'Algeria' 'Oman' 'French Guiana' 'Azerbaijan' 'Latvia' 'Kyrgyzstan'
#  'Romania' 'Belarus' 'Peru, Italy' 'Moldova, Republic of' 'Kazakhstan'
#  'Saudi Arabia' 'Ukraine, Spain' 'Liechtenstein' 'Solomon Islands'
#  'Guinea' 'Guam' 'Somalia' 'Suriname']
# DataFrame successfully saved to: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/df_Primarystudies_Country.csv
# Total entries in the processed dataset: 22772

# %%
#dictionaries with the corrected / reclassified elements
control_mapping = {
    'no biochar': 'no biochar',
    'no fire': 'no fire',
    'no cover crops': 'no cover crops',
    'farmland or abandonned land': 'abandoned land',
    'other land': 'other land',
    'cropland (previous land use)': 'cropland',
    'forest (previous land use)': 'forest',
    'grassland (previous land use)': 'grassland',
    'plantation (previous land use)': 'forest',
    'non fertilized control': 'no fertilization',
    'fertilized control': 'fertilization',
    'unfertilized cntrol': 'no fertilization',
    'pasture/grassland (previous land use)': 'grassland',
    'all previous land use': 'all land use',
    'agriculture (previous land use)': 'cropland',
    'uncultivated/other (previous land use)': 'abandoned land',
    'forest plantation (previous land use)': 'forest',
    'no fire, no harvest': 'no fire, no harvest',
    'no harvest': 'no harvest',
    'urea': 'fertilization, N',
    'other grazing practices': 'grassland',
    'no amendments': 'no amendments',
    'no residues amendments': 'no amendments',
    'various land': 'various land use',
    'no ferti': 'no fertilization',
    'synthetic fertilizer only': 'fertilization',
    'without fresh c input': 'no carbon added',
    'grassland': 'grassland',
    'no fertilizer added': 'no fertilization',
    'simplified rotation': 'rotation',
    'mineral only fertilization': 'fertilization',
    'no organic material added': 'no fertilization',
    'no organic amendments': 'no amendments',
    'inorganic fertilizer': 'fertilization',
    'no fertilization': 'no fertilization',
    'mineral fertilization': 'fertilization',
    'conventional management (no c input)': 'conventional',
    'conventional management': 'conventional',
    'synthetic n': 'fertilization, N',
    'straw removal': 'no straw',
    'no straw retention': 'no straw',
    'no straw return': 'no straw',
    'no n fertilization': 'no fertilization',
    'organic amendment': 'amendment',
    'no input at all': 'no fertilization',
    'n fertilizer': 'fertilization, N',
    'conventional management (synthetic fertilization, conventional tillage and non-use of organic inputs, except crop residues in some cases)': 'conventional',
    'no grazing': 'no grazing',
    'no grazing exclusion': 'no grazing',
    'continuous grazing': 'grassland',
    'no drought': 'no drought',
    'no irrigation': 'no irrigation',
    'non freeze-thaw': 'no freeze-thaw',
    'no watering': 'no irrigation',
    'no warming': 'no warming',
    'no wetting effect': 'no irrigation',
    'no co2 enrichment': 'no CO2',
    'no elevated c02': 'no CO2',
    'all': 'all',
    'no n added': 'no fertilization',
    'non-warming': 'no warming',
    'no snow manipulation': 'no snow removal',
    'no rainfall reduction': 'no drought',
    'no c02 elevation and non ferti': 'no CO2',
    'no c02 elevation': 'no CO2',
    'no n ferti': 'no fertilization',
    'before-after': 'before and after',
    'previous land-use': 'other land use',
    'cropland': 'cropland',
    'degraded fallow': 'fallow',
    'unshaded system': 'unshaded',
    'underutilised land': 'underuse',
    'fallow land': 'fallow',
    'fallow': 'fallow',
    'unshaded': 'unshaded',
    'underutilized': 'underuse',
    'sole cropping, continuous cropping without trees, and plots outside tree crowns in the case of parklands': 'cropland',
    'tillage: conventional': 'conventional',
    'pasture': 'grassland',
    'forest or agricultural land use or pasture': 'various land use',
    'agriculture land': 'cropland',
    'forest': 'forest',
    'uncultivated land': 'underuse',
    'agrisilviculture': 'agrosilviculture',
    'cropland/forest land/grassland to trop_agrosilvopasture': 'various land use',
    'forest or agricultural land use or pasture or unultivated': 'various land use',
    'grassland/other land to trop_silvopasture': 'grassland',
    'forest or agricultural land use': 'cropland and forest',
    'grassland_other land to trop_agrisilvopasture': 'grassland',
    'cropland->multistrata systems': 'cropland',
    'cropland/forest to temp_agrisilviculture': 'cropland and forest',
    'forest/pasture to temp_silvopasture': 'forest and grassland',
    'other land to temp_agrosilvopasture': 'other land use',
    'cropland/grassland to arid_agrisilviculture': 'cropland and grassland',
    'cropland/grassland/other land to trop_agrisilviculture': 'cropland and grassland',
    'cropland/forest to trop_agrisilviculture': 'cropland and forest',
    'forest land/grassland to trop_agrosilvopasture': 'forest and grassland',
    'cropland/forest land/grassland to silvopasture': 'cropland and forest',
    'cropland/forest land/grassland/other lands to agrisilviculture': 'various land use',
    'forest land/grassland to silvopasture': 'forest and grassland',
    'bare fallow': 'fallow',
    'no temperature increase': 'no warming',
    'no precipitation increase': 'no irrigation',
    'no precipitation reduction': 'no drought',
    'no np fertilization': 'no fertilization',
    'no p fertilization': 'no fertilization',
    'monoculture': 'monoculture',
    'rotation with lower functional richness': 'rotation',
    'non agroforestry': 'no agroforestry',
    'cropland or pasture': 'cropland',
    'no hedgerow': 'no hedgerow',
    'no grass strips': 'no grassland',
    'conventional agriculture': 'conventional',
    'clean tillage': 'conventional',
    'non n addition': 'no fertilization',
    'no n addition': 'no fertilization',
    'no ash application': 'no amendments',
    'unfertilized': 'no fertilization',
    'without earthworms': 'no earthworms',
    'no p': 'no fertilization',
    'no se fertilization': 'no fertilization',
    'organic fertilizer (initial stage)': 'fertilization',
    'combined chemical + organic fertilizer (initial stage)': 'fertilization',
    'no fertilizer (initial stage)': 'no fertilization',
    'chemical fertilizer (initial stage)': 'fertilization',
    'no straw return (initial stage)': 'no straw',
    'no retention': 'no straw',
    'no manure noferti': 'no fertilization',
    'no manure': 'no fertilization',
    'no manure, no ferti': 'no fertilization',
    '100% inorganic n addition': 'fertilization, N',
    'no inorganic n addition': 'no fertilization',
    'one shot inorganic n addition': 'fertilization, N',
    'top placement of inorganic n addition': 'fertilization, N',
    'normal inorganic n addition': 'fertilization, N',
    'no liming': 'no fertilization',
    'no p addition': 'no fertilization',
    'no fertilizer, liming and grazing': 'no fertilization',
    'continuous flooding': 'flooding',
    'young ex arable': 'cropland',
    'arable': 'cropland',
    'ancient grassland': 'grassland',
    'conventional till': 'conventional',
    'non afforested': 'no forest',
    'agricultural': 'cropland',
    'agriculture cultivated': 'cropland',
    'agriculture unknown': 'cropland',
    'all land use': 'various land use',
    'agriculture forage': 'cropland',
    'wildland': 'various land use',
    'agriculture (cropland + pasture) (previous land use)': 'cropland',
    'pasture (previous land use)': 'grassland',
    'natural grassland (previous land use)': 'grassland',
    'former land use - cropland': 'cropland',
    'no afforestation': 'no forest',
    'former land use - grassland': 'grassland',
    'former land use - heathland': 'heathland',
    'former land use - barrenland': 'barrenland',
    'natural grassland': 'grassland',
    'no afforestation (previous land use)': 'no forest',
    'non forested land': 'no forest',
    'initial soc stock': 'no fertilization',
    'cropland/pasture/bare area': 'cropland and grassland',
    'bare area': 'bare soil',
    'medium c input': 'fertilization',
    'conventional practices': 'conventional',
    'native': 'native',
    'other land use': 'other land use',
    'cultivated land': 'cropland',
    'wood land': 'shrubland',
    'natural vegetation': 'native',
    'primary forest': 'forest',
    'secondary forest': 'forest',
    'forest all': 'forest',
    'no forest harvesting': 'forest',
    'grassland or pasture': 'grassland',
    'barren land': 'barrenland',
    'primary or secondary forest': 'forest',
    'grassland and cropland': 'cropland and grassland',
    'continuous maize': 'monoculture',
    'no fertilizer': 'no fertilization',
    'no-tillage': 'no till',
    'undisturbed mangrove (previous land use)': 'native',
    'crop': 'cropland',
    'overall': 'all',
    'crop (previous land use)': 'cropland',
    'savanna (previous land use)': 'savanna',
    'farmland (previous land use)': 'cropland',
    'all previous land uses': 'various land use',
    'primary forest (previous land use)': 'forest',
    'secondary forest (previous land use)': 'forest',
    'arable land': 'cropland',
    'forest land': 'forest',
    'perennial plantation (previous land use)': 'forest',
    'native forest (previous land use)': 'native',
    'long fallow swidden': 'fallow',
    'uncut control': 'native',
    'natural forest': 'native',
    'grazed grassland (previous land use)': 'grassland',
    'pure stand norway spruce': 'fallow',
    'shrub encroachment': 'shrubland',
    'non-crop land': 'forest',
    'plantation': 'forest',
    'wetland': 'wetland',
    'control wetland within 10km, or before-after': 'wetland',
    'previous land: forest': 'forest',
    'grass': 'grassland',
    'previous land: grass': 'grassland',
    'natural wetland': 'wetland',
    'woody plants retained': 'shrubland',
    'before biological intervention': 'non explicit',
    'before exclosure': 'non explicit',
    'before bunds': 'non explicit',
    'before bunds and biological intervention': 'non explicit',
    'before terrassing': 'non explicit',
    'before conservation agriculture': 'non explicit',
    'no improved management practice': 'non explicit',
    'no organic manure': 'no fertilization',
    'mineral fertilizer': 'fertilization',
    'conventional tillage': 'conventional',
    'no organic matter input': 'no fertilization',
    'no co2 change': 'no CO2',
    'no fetilizer': 'no CO2',
    'no till': 'no till',
    'residue removal': 'no straw',
    'residue removed': 'no straw',
    'high intensity tillage (e.g. mouldboard plough and subsoiling)': 'conventional',
    'intermediate tillage (e.g. chisel, disk, harrow and mulch plough)': 'conventional',
    'chemical fertilization application': 'fertilization',
    'plow tillage with residue removal': 'conventional',
    'no litter removal': 'no till',
    'no litter addition': 'no litter',
    'no litter exclusion': 'litter',
    'no litter excluision': 'litter',
    'plow tillage + residue removed': 'conventional',
    'plow tillage + residue retention': 'conventional',
    'no-tillage (previous land-use)': 'no till',
    'savannah/forest': 'savanna',
    'savannah': 'savanna',
    'full tillage': 'conventional',
    'conventional farming': 'conventional',
    'no plastic film': 'no cover',
    'no organic c addition': 'no fertilization',
    'before after': 'before and after',
    'non removal': 'no till',
    '-': 'none',
    '1' : 'none',
    'crop frequency: single (1 crop per year)': 'cropland',
    'high intensity tillage': 'conventional',
    'intermediate intensity tillage': 'conventional',
    'conventional tillage without residues': 'conventional',
    'tillage': 'conventional',
    'conventionnal tillage': 'conventional',
    'bare soil': 'bare soil',
    'no amendemenrts': 'no amendments',
    'traditional tillage + no cover crop': 'conventional',
    'traditional tillage': 'conventional',
    'no high biomass rice cultivar': 'low biomass',
    'non polluted soils': 'no polluted',
    'no pollution': 'no polluted',
    'non shrub-encroached grassland': 'grassland',
    'no acid addition': 'no amendments',
    'intercanopy microsite': 'intercanopy',
    'no biotic disturbance': 'native',
    'no co2, no warming': 'no CO2, no warming',
    'no co2': 'no CO2',
    'nondegraded alpine meadow': 'alpine',
    'conventional forest harvest (tree stems)': 'forest',
    'unharvested forests': 'forest',
    'natural succession': 'native',
    'non harvested + chronosequence': 'no harvest',
    'no c02 + drought': 'no CO2, no irrigation',
    'no co2 + drought': 'no CO2, no irrigation',
    'no co2 + rainfall': 'no CO2, irrigation',
    'no co2+n': 'no CO2, fertilization, N',
    'no co2 + n': 'no CO2, fertilization, N',
    'no c02+n': 'no CO2, fertilization, N',
    'no co2 + warming': 'no CO2, Warming',
    'no co2+ warming': 'no CO2, Warming',
    'no c02 + warming': 'no CO2, Warming',
    'no c02+ warming': 'no CO2, Warming',
    'no n + drought': 'no N, no irrigation',
    'no n+ rainfall': 'no N, irrigation',
    'no n+ p addition': 'no N, yes P',
    'no n +rainfall': 'no N, irrigation',
    'no warming + drought': 'no warming, no irrigation',
    'no warming + rainfall': 'no warming, irrigation',
    'no increase in rainfall': 'no increase in rainfall',
    'no warming + n': 'no warming, fertilization, N',
    'no warming +n': 'no warming, fertilization, N',
    'no rainfall': 'no irrigation',
    'no n': 'no N',
    'no n+p addition': 'no N, no P',
    'non plant invasion': 'controlled vegetation',
    'non overgrazing': 'no grassland',
    'whole tree harvest': 'forest harvest',
    'no thinning': 'no controlled vegetation',
    'conifer stands': 'forest',
    'non treated urea': 'fertilization, N',
    'degraded grassland': 'degraded grassland',
    'urea (> 200 kg n ha-1)': 'fertilization, N',
    'normal n fertilizer': 'fertilization, N',
    'no straw': 'no Straw',
    'npk fertilizer': 'fertilization, N',
    'rice only': 'monoculture',
    'n fertilizer (294 kg n ha-1)': 'fertilization, N',
    'n fertilizer (320 kg n ha-1)': 'fertilization, N',
    'n fertilizer (264 kg n ha-1)': 'fertilization, N',
    'n fertilizer (268 kg n ha-1)': 'fertilization, N',
    'grazing': 'grassland',
    'heavy grazing': 'grassland',
    'without crop mixture': 'no crop mixture',
    'no intercropping': 'no intercropping',
    'no earthworms or reduced earthworm abundance': 'no earthworms',
    'monoculture plots': 'monoculture'
}


land_use_mapping = {
    'heatland': 'heathland',
    'various land use': 'various',
    'other land : various': 'various',
    'other land': 'various'
}

intervention_mapping = {
    'global changes/management': 'global changes, management',
    'land use change/management': 'land use change, management'
}

# %%
df_effects.columns
# Out:
# Index(['ID', 'Land_use', 'Intervention', 'Sub_Cat_intervention', 'details',
#        'Control (C)', 'treatment_authors', 'summary_effect_size', 'management',
#        'method', 'species', 'region_climate', 'soil', 'depth_original',
#        'depth', 'group_depth', 'depth2', 'Duration', 'carbon', 'unit',
#        'Rateyr', 'Log_scale', 'metric', 'Outcome', 'Sub_cat_outcome',
#        'details_outcome', 'lower_CI', 'Effect size', 'upper_CI', 'p_value',
#        'N_paired_data', 'ES_SE'],
#       dtype='object')

# %%
# Clean column names
df_effects = clean_column_names(df_effects)

# Normalize relevant text columns
text_columns = ['land_use', 'intervention', 'sub_cat_intervention', 'details',
       'control (c)', 'treatment_authors', 'summary_effect_size', 'management',
       'method', 'species', 'region_climate', 'soil', 'carbon', 'unit',
       'rateyr', 'log_scale', 'metric', 'outcome', 'sub_cat_outcome',
       'details_outcome', 'lower_ci', 'effect size', 'upper_ci', 'p_value',
       'n_paired_data', 'es_se',]
for col in text_columns:
    df_effects = normalize_text(df_effects, col)

# %%
df_effects.head()
# Out:
#                        id  land_use intervention  sub_cat_intervention  \
# 0  07_Sagrilo et al, 2015  cropland   management  amendments pyrogenic
# 1  07_Sagrilo et al, 2015  cropland   management  amendments pyrogenic
# 2  07_Sagrilo et al, 2015  cropland   management  amendments pyrogenic
# 3  07_Sagrilo et al, 2015  cropland   management  amendments pyrogenic
# 4  07_Sagrilo et al, 2015  cropland   management  amendments pyrogenic
#
#               details control (c) treatment_authors summary_effect_size  \
# 0  amendments:biochar  no biochar           biochar                 NaN
# 1  amendments:biochar  no biochar           biochar                 NaN
# 2  amendments:biochar  no biochar           biochar                 NaN
# 3  amendments:biochar  no biochar           biochar                 NaN
# 4  amendments:biochar  no biochar           biochar                 NaN
#
#               management method  ... metric outcome sub_cat_outcome  \
# 0       pyc:soc ratio <2      -  ...  ratio     ghg             co2
# 1  overall pyc:soc ratio      -  ...  ratio     ghg             co2
# 2       pyc:soc ratio >2      -  ...  ratio     ghg             co2
# 3       pyc:soc ratio >2      -  ...  ratio     ghg             co2
# 4       pyc:soc ratio <2      -  ...  ratio     ghg             co2
#
#   details_outcome           lower_ci       effect size          upper_ci  \
# 0       emissions  0.932926829268292  1.03353658536585  1.14329268292682
# 1       emissions   1.14329268292682  1.27134146341463  1.43597560975609
# 2       emissions   1.55487804878048  1.98475609756097  2.63871951219512
# 3       emissions               1.57              2.55              4.53
# 4       emissions               1.05              1.16              1.27
#
#   p_value n_paired_data es_se
# 0     NaN           179   NaN
# 1     NaN           268   NaN
# 2     NaN            89   NaN
# 3     NaN            23   NaN
# 4     NaN            29   NaN
#
# [5 rows x 32 columns]

# %%
#mapping and replacements

df_effects['land_use'] = df_effects['land_use'].replace(land_use_mapping)

df_effects['intervention'] = df_effects['intervention'].replace(intervention_mapping)

#control (C) mapping
df_effects = map_control_values(df_effects, 'control (c)', control_mapping)

# %%
df_effects['duration_standardized'] = df_effects['duration'].apply(standardize_duration)

df_effects['depth'] = df_effects['depth'].apply(normalize_depth)

# %%
# Standardize metrics and filter data
metrics_to_keep = ['ratio', 'percent change', "hedge's d", 'standardized difference']
df_effects_filtered = standardize_metrics(df_effects, metrics_to_keep)

# Filter for 'soil carbon'
df_effects_filtered = df_effects_filtered[df_effects_filtered['outcome'].str.lower() == 'soil carbon']

# Convert percent to ratio where applicable
condition = df_effects_filtered['metric'] == 'percent change'
columns_to_transform = ['lower_ci', 'effect size', 'upper_ci']
df_effects_filtered = apply_transformations(df_effects_filtered, condition, columns_to_transform)

# %%
#Save the filtered DataFrame
full_path = os.path.join(paths['processed_data_path'], 'df_effects_SOC.csv')
df_effects_filtered.to_csv(full_path, index=False)

print(f'DataFrame successfully saved to: {full_path}')
print(f'Total entries in the processed dataset: {len(df_effects_filtered)}')
# Out:
# DataFrame successfully saved to: /content/drive/My Drive/2024/DataScience/CarbonSequestration/01-CarbonSequestration/01-Data/02-ProcessedData/df_effects_SOC.csv
# Total entries in the processed dataset: 5172
